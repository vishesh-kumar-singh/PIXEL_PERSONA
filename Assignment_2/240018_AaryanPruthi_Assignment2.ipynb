# %% [markdown]
# **ASSIGNMENT_2 LOGISTIC REGRESSION**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import warnings
from sklearn.metrics import accuracy_score
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('loan_data.csv')
data.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...

# %% [markdown]
# **THE SHAPE OF THE DATA**

# %%
data.shape
# Out:
# (45000, 14)

# %% [markdown]
# **THE DATA AND ITS DESCRIPTION :**

# %%
data.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  45000.000000   4.500000e+04    45000.000000  45000.000000
# mean      27.764178   8.031905e+04        5.410333   9583.157556
# std        6.045108   8.042250e+04        6.063532   6314.886691
# min       20.000000   8.000000e+03        0.000000    500.000000
# 25%       24.000000   4.720400e+04        1.000000   5000.000000
# 50%       26.000000   6.704800e+04        4.000000   8000.000000
# 75%       30.000000   9.578925e+04        8.000000  12237.250000
# max      144.000000   7.200766e+06      125.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   45000.000000         45000.000000                45000.000000
# mean       11.006606             0.139725                    5.867489
# std         2.978808             0.087212                    3.879702
# min         5.420000             0.000000                    2.000000
# ...

# %% [markdown]
# **DATA PREPROCESSING STEP:REMOVING UNWANTED COLUMNS**

# %%
df = data.drop(["person_age","person_gender","person_income","person_education","person_emp_exp","person_home_ownership","loan_intent","previous_loan_defaults_on_file"],axis = 'columns')
df
# Out:
#        loan_amnt  loan_int_rate  loan_percent_income  \
# 0        35000.0          16.02                 0.49
# 1         1000.0          11.14                 0.08
# 2         5500.0          12.87                 0.44
# 3        35000.0          15.23                 0.44
# 4        35000.0          14.27                 0.53
# ...          ...            ...                  ...
# 44995    15000.0          15.66                 0.31
# 44996     9000.0          14.07                 0.14
# 44997     2771.0          10.02                 0.05
# 44998    12000.0          13.23                 0.36
# 44999     6665.0          17.05                 0.13
#
#        cb_person_cred_hist_length  credit_score  loan_status
# 0                             3.0           561            1
# 1                             2.0           504            0
# 2                             3.0           635            1
# 3                             2.0           675            1
# ...

# %% [markdown]
# **DATA PREPROCESSING STEP:DELETING ROWS WITH NaN VALUES**

# %%
df.dropna(inplace = True)
df
# Out:
#        loan_amnt  loan_int_rate  loan_percent_income  \
# 0        35000.0          16.02                 0.49
# 1         1000.0          11.14                 0.08
# 2         5500.0          12.87                 0.44
# 3        35000.0          15.23                 0.44
# 4        35000.0          14.27                 0.53
# ...          ...            ...                  ...
# 44995    15000.0          15.66                 0.31
# 44996     9000.0          14.07                 0.14
# 44997     2771.0          10.02                 0.05
# 44998    12000.0          13.23                 0.36
# 44999     6665.0          17.05                 0.13
#
#        cb_person_cred_hist_length  credit_score  loan_status
# 0                             3.0           561            1
# 1                             2.0           504            0
# 2                             3.0           635            1
# 3                             2.0           675            1
# ...

# %% [markdown]
# **LABELLING THE DATA SET AS X AND Y  I.E INPUT AND OUTPUT**

# %%
X= df.drop("loan_status",axis = 'columns')
X
# Out:
#        loan_amnt  loan_int_rate  loan_percent_income  \
# 0        35000.0          16.02                 0.49
# 1         1000.0          11.14                 0.08
# 2         5500.0          12.87                 0.44
# 3        35000.0          15.23                 0.44
# 4        35000.0          14.27                 0.53
# ...          ...            ...                  ...
# 44995    15000.0          15.66                 0.31
# 44996     9000.0          14.07                 0.14
# 44997     2771.0          10.02                 0.05
# 44998    12000.0          13.23                 0.36
# 44999     6665.0          17.05                 0.13
#
#        cb_person_cred_hist_length  credit_score
# 0                             3.0           561
# 1                             2.0           504
# 2                             3.0           635
# 3                             2.0           675
# 4                             4.0           586
# ...

# %%
Y = df["loan_status"]
Y
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 44995    1
# 44996    1
# 44997    1
# 44998    1
# 44999    1
# Name: loan_status, Length: 45000, dtype: int64

# %% [markdown]
# **IMPLEMENTING THE LOGISTIC REGRESSION FUNCTION-IT IS MODEL 2**

# %%
class myLogistic_Regression() :
    def __init__( self, learning_rate, iterations ) :
        self.learning_rate = learning_rate
        self.iterations = iterations

    def fit( self, X, Y ) :

        self.m, self.n = X.shape

        self.W = np.zeros( self.n )
        self.b = 0
        self.X = X
        self.Y = Y



        for i in range( self.iterations) :
            self.update_weights()
        return self


    def update_weights( self ) :
        A = 1 / ( 1 + np.exp( - ( self.X.dot( self.W ) + self.b ) ) )


        tmp = ( A - self.Y.T )
        tmp = np.reshape( tmp, self.m )
        dW = np.dot( self.X.T, tmp ) / self.m
        db = np.sum( tmp ) / self.m

        self.W = self.W - self.learning_rate * dW
        self.b = self.b - self.learning_rate* db

        return self

    def predict( self, X ) :
        Z = 1 / ( 1 + np.exp( - ( X.dot( self.W ) + self.b ) ) )
        Y = np.where( Z > 0.5, 1, 0 )
        return Y

# %% [markdown]
# **APPLYING THE IMPORTED MODEL AND THE IMPLEMENTED MODEL AFTER SPLITTING THE DATA SET**

# %%
X_train,X_test,Y_train,Y_test= train_test_split(X,Y,test_size = 1/3,random_state = 0)
model1 = LogisticRegression()
# MODEL 1 IS THE IMPORTED MODEL
model1.fit(X_train,Y_train)
Y_pred1 = model1.predict(X_test)
model2 = myLogistic_Regression(learning_rate = 0.001,iterations = 1000)
model2.fit(X_train,Y_train)
Y_pred2 = model2.predict(X_test)

# %% [markdown]
# **USING THE ACCURACY _SCORE FUNCTION FROM THE SKLEARN.METRICS LIBRARY AND FINDING THE ACCURACY OF THE 2 MODELS**

# %%
accuracy = accuracy_score(Y_test,Y_pred1)
print("Accuracy of Imported Model is ",accuracy)
accuracy = accuracy_score(Y_test,Y_pred2)
print("Accuracy of My Model is ",accuracy)
# Out:
# Accuracy of Imported Model is  0.8274666666666667
# Accuracy of My Model is  0.7809333333333334
