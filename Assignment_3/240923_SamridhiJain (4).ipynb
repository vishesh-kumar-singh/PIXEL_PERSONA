# %% [markdown]
# ## **Linear Regression**
# We will use Linear regression for predicting house prices
#
# We are using a Kaggle dataset- https://www.kaggle.com/harlfoxem/housesalesprediction

# %%
# Lets import required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### **Dataset Preparation**

# %%
# Execute this cell for loading dataset in a pandas dataframe

from IPython.display import clear_output
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=16x6-8Znn2T50zFwVvKlzsdN7Jd1hpjct' -O Linear_regression_dataset

data_df = pd.read_csv("Linear_regression_dataset")
# Out:
# --2024-12-09 17:02:11--  https://docs.google.com/uc?export=download&id=16x6-8Znn2T50zFwVvKlzsdN7Jd1hpjct
# Resolving docs.google.com (docs.google.com)... 172.217.0.78, 2607:f8b0:4025:810::200e
# Connecting to docs.google.com (docs.google.com)|172.217.0.78|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=16x6-8Znn2T50zFwVvKlzsdN7Jd1hpjct&export=download [following]
# --2024-12-09 17:02:11--  https://drive.usercontent.google.com/download?id=16x6-8Znn2T50zFwVvKlzsdN7Jd1hpjct&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.250.65.97, 2607:f8b0:4025:804::2001
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.250.65.97|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2515206 (2.4M) [application/octet-stream]
# Saving to: ‘Linear_regression_dataset’
#
# Linear_regression_d 100%[===================>]   2.40M  --.-KB/s    in 0.09s
#
# 2024-12-09 17:02:15 (28.0 MB/s) - ‘Linear_regression_dataset’ saved [2515206/2515206]

# %%
# Lets have a quick Look at dataset

print("(No of rows, No of Columns) = ",data_df.shape)
data_df.head()
# Out:
# (No of rows, No of Columns) =  (21613, 21)
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# So there are **19** features (of course we will not use id as feature :) ), and 1 variable to predict(price)
#
# But note that the **date** column contain strings so first we will remove T00.. part from it and than convert it to numpy array.

# %%
data_df['date'] = data_df['date'].str.replace('T000000', '', regex=False)                                     # Remove T000000 part from data column. Hint: search about .str.replace() method. :)

data_array = data_df.drop(columns=['id'])                                        # Create a numpy array which does not have "id" field
assert (data_array.shape == (21613,20))

data_df.head()
# Out:
#            id      date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520  20141013  221900.0         3       1.00         1180      5650
# 1  6414100192  20141209  538000.0         3       2.25         2570      7242
# 2  5631500400  20150225  180000.0         2       1.00          770     10000
# 3  2487200875  20141209  604000.0         4       3.00         1960      5000
# 4  1954400510  20150218  510000.0         3       2.00         1680      8080
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     2.0           0     0  ...      7        2170            400      1951
# 2     1.0           0     0  ...      6         770              0      1933
# 3     1.0           0     0  ...      7        1050            910      1965
# 4     1.0           0     0  ...      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# Now the next task is **normalization**.
#
# We will scale each column of dataset by x -> (x-u)/s
#
# where u is mean(x), and s is standard deviation of u

# %%
data_array['date']=np.array(data_array['date'],dtype=np.int32)
mean = data_array.mean()                                  # this should be an array, each entry should be mean of a column
sd = data_array.std()                                   # this should be an array, each entry should be standard deviation of a column

data_array_norm = (data_array - mean)/sd

print(data_array_norm.shape)
# Out:
# (21613, 20)

# %% [markdown]
# The last step is to make train and test dataset and to create seperate vector for price

# %%
labels = data_array['price']                                                                                                        # extract the price column from data

x_array_norm = data_array_norm.drop(columns=['price'])                                                                                                     # delete the price column from data_array_norm. Hint: use np.delete()

x_train, x_test, y_train, y_test = train_test_split(x_array_norm,labels,test_size=0.15,random_state=42,shuffle=True)    # splitting data into test and train set.

print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (18371, 19) (3242, 19) (18371,) (3242,)

# %% [markdown]
# ### **Loss and gradient descent**
# We will use mean squared error(MSE) as loss
#
# Use the gradient descent algorithm which you learned from tutorials
#
# Your task is to complete the following functions

# %%
def loss(y_pred,y_true):
  """
  input:
  y_pred = [array] predicted value of y
  y_true = [array] ground truth

  output:
  mse: [scalar] the MES loss
  """
  mse = np.mean((y_pred-y_true)**2)             # fill code here
  return mse

# %%
def y(x,a,b):
  """
  This function should return predicted value of y = ax+b
  input:
  x: [array] the feature vector of shape (m,n)
  a: [array] weights of shape (n,)
  b: [scalar] bias

  output:
  y_pred: [array] predicted value of y of shape (m,)
  """

  m,n = x.shape
  y_pred = np.dot(x,a)+b             #dot function for matrix multiplication     # fill code here

  assert(y_pred.shape == (m,))
  return y_pred

# %%
def gradient(x,a,b,y_true):
  """
  This function shoud return gradient of loss
  input:
  x: [array] the feature vector of shape (m,n)
  a: [array] weights of shape (n,)
  b: [scalar] bias
  y_true: [array] ground truth of shape (m,)

  output:
  grad: [tuple] a tuple (derivative with respect to a[array of shape(n,)], derivative with respect to b[scalar])
  """
  m,n = x.shape
  yp = y(x,a,b)

  da = (2 / m) * np.dot(x.T, yp-y_true)              # write code to calculate derivative of loss with respect to a
  db = (2 / m) * np.sum(yp-y_true)             # write code to calculate derivative of loss with respect to b

  assert(da.shape ==(n,))
  return (da,db)

# %%
def gradient_descent(x,y_true,learning_rate=0.01,epochs = 10):
  """
  This function perfroms gradient descent and minimizes loss
  input:
  x: [array] the feature vector of shape (m,n)
  y_true: [array] ground truth of shape (m,)

  output:
  loss: [array] of size (epochs,)
  weights: [tuple] (a,b)
  """
  m,n = x.shape
  loss_mse = []                                 # initialize empty list to store loss
  a = np.zeros(n)                                      # initialize a- weights and b- bias
  b = 0

  for i in range(epochs):
    # calculate derivative using gradient() function
    # apply gradient descent now to update a and b
    da,db = gradient(x,a,b,y_true)
    a-=learning_rate*da
    b-=learning_rate*db
    l_mse = loss(y(x,a,b),y_true)                              # calculate loss at this point
    loss_mse.append(l_mse)
    print("Epoch ",i+1," Completed!","loss = ",l_mse)

  print("Training completed!!")

  assert(a.shape==(n,))

  return (loss_mse,a,b)

# %% [markdown]
# ### **Training**

# %%
epochs = 500             # tweak this!!!
learn_rate = 0.01         # choose learning rate wisely otherwise loss may diverge!!

train_loss,a,b = gradient_descent(x_train, y_train, learn_rate, epochs)
# Out:
# Epoch  1  Completed! loss =  397185962226.43665
# Epoch  2  Completed! loss =  375665446993.2915
# Epoch  3  Completed! loss =  356348977931.93054
# Epoch  4  Completed! loss =  338892483631.1527
# Epoch  5  Completed! loss =  323015325717.28076
# Epoch  6  Completed! loss =  308488029532.31104
# Epoch  7  Completed! loss =  295122420645.2688
# Epoch  8  Completed! loss =  282763693398.07275
# Epoch  9  Completed! loss =  271284031140.54977
# Epoch  10  Completed! loss =  260577472818.45294
# Epoch  11  Completed! loss =  250555780784.4974
# Epoch  12  Completed! loss =  241145113027.73645
# Epoch  13  Completed! loss =  232283341806.34952
# Epoch  14  Completed! loss =  223917891805.34528
# Epoch  15  Completed! loss =  216003995934.46176
# Epoch  16  Completed! loss =  208503286945.089
# Epoch  17  Completed! loss =  201382659151.4105
# Epoch  18  Completed! loss =  194613347471.14087
# Epoch  19  Completed! loss =  188170181382.01245
# Epoch  20  Completed! loss =  182030979724.62216
# Epoch  21  Completed! loss =  176176058974.13892
# Epoch  22  Completed! loss =  170587832976.76877
# Epoch  23  Completed! loss =  165250486461.8776
# Epoch  24  Completed! loss =  160149708106.04178
# Epoch  25  Completed! loss =  155272471708.6035
# Epoch  26  Completed! loss =  150606856274.03903
# Epoch  27  Completed! loss =  146141897592.562
# Epoch  28  Completed! loss =  141867465353.5287
# Epoch  29  Completed! loss =  137774160985.9473
# Epoch  30  Completed! loss =  133853232352.55171
# Epoch  31  Completed! loss =  130096502173.29372
# Epoch  32  Completed! loss =  126496307656.73341
# Epoch  33  Completed! loss =  123045449302.52834
# Epoch  34  Completed! loss =  119737147228.24666
# Epoch  35  Completed! loss =  116565003687.663
# Epoch  36  Completed! loss =  113522970700.49374
# Epoch  37  Completed! loss =  110605321917.19095
# Epoch  38  Completed! loss =  107806628006.58247
# Epoch  39  Completed! loss =  105121734986.55856
# Epoch  40  Completed! loss =  102545745024.88176
# Epoch  41  Completed! loss =  100073999323.52951
# Epoch  42  Completed! loss =  97702062769.78125
# Epoch  43  Completed! loss =  95425710093.75551
# Epoch  44  Completed! loss =  93240913317.87944
# Epoch  45  Completed! loss =  91143830320.91443
# Epoch  46  Completed! loss =  89130794369.34099
# Epoch  47  Completed! loss =  87198304493.46878
# Epoch  48  Completed! loss =  85343016605.66858
# Epoch  49  Completed! loss =  83561735274.48828
# Epoch  50  Completed! loss =  81851406081.82094
# Epoch  51  Completed! loss =  80209108501.29951
# Epoch  52  Completed! loss =  78632049245.15666
# Epoch  53  Completed! loss =  77117556034.27571
# Epoch  54  Completed! loss =  75663071752.36346
# Epoch  55  Completed! loss =  74266148950.33904
# Epoch  56  Completed! loss =  72924444671.34329
# Epoch  57  Completed! loss =  71635715570.39107
# Epoch  58  Completed! loss =  70397813305.73491
# Epoch  59  Completed! loss =  69208680181.58815
# Epoch  60  Completed! loss =  68066345024.05077
# Epoch  61  Completed! loss =  66968919273.957245
# Epoch  62  Completed! loss =  65914593281.97926
# Epoch  63  Completed! loss =  64901632792.71059
# Epoch  64  Completed! loss =  63928375605.67254
# Epoch  65  Completed! loss =  62993228402.23715
# Epoch  66  Completed! loss =  62094663728.394264
# Epoch  67  Completed! loss =  61231217124.108986
# Epoch  68  Completed! loss =  60401484390.74459
# Epoch  69  Completed! loss =  59604118988.6733
# Epoch  70  Completed! loss =  58837829557.77963
# Epoch  71  Completed! loss =  58101377554.082634
# Epoch  72  Completed! loss =  57393574996.175674
# Epoch  73  Completed! loss =  56713282315.61008
# Epoch  74  Completed! loss =  56059406305.73771
# Epoch  75  Completed! loss =  55430898163.8834
# Epoch  76  Completed! loss =  54826751622.0428
# Epoch  77  Completed! loss =  54246001161.59993
# Epoch  78  Completed! loss =  53687720307.83379
# Epoch  79  Completed! loss =  53151020000.2363
# Epoch  80  Completed! loss =  52635047034.89904
# Epoch  81  Completed! loss =  52138982575.44275
# Epoch  82  Completed! loss =  51662040729.16575
# Epoch  83  Completed! loss =  51203467185.27437
# Epoch  84  Completed! loss =  50762537912.23321
# Epoch  85  Completed! loss =  50338557911.43599
# Epoch  86  Completed! loss =  49930860024.54939
# Epoch  87  Completed! loss =  49538803792.024284
# Epoch  88  Completed! loss =  49161774360.40226
# Epoch  89  Completed! loss =  48799181436.169205
# Epoch  90  Completed! loss =  48450458284.025085
# Epoch  91  Completed! loss =  48115060767.54833
# Epoch  92  Completed! loss =  47792466430.336784
# Epoch  93  Completed! loss =  47482173615.80334
# Epoch  94  Completed! loss =  47183700623.89651
# Epoch  95  Completed! loss =  46896584903.10113
# Epoch  96  Completed! loss =  46620382276.15614
# Epoch  97  Completed! loss =  46354666198.00219
# Epoch  98  Completed! loss =  46099027044.54413
# Epoch  99  Completed! loss =  45853071430.88164
# Epoch  100  Completed! loss =  45616421557.72518
# Epoch  101  Completed! loss =  45388714584.77563
# Epoch  102  Completed! loss =  45169602029.90316
# Epoch  103  Completed! loss =  44958749193.01594
# Epoch  104  Completed! loss =  44755834603.559975
# Epoch  105  Completed! loss =  44560549490.6412
# Epoch  106  Completed! loss =  44372597274.80647
# Epoch  107  Completed! loss =  44191693080.56478
# Epoch  108  Completed! loss =  44017563268.771065
# Epoch  109  Completed! loss =  43849944988.03515
# Epoch  110  Completed! loss =  43688585744.355576
# Epoch  111  Completed! loss =  43533242988.21404
# Epoch  112  Completed! loss =  43383683718.40012
# Epoch  113  Completed! loss =  43239684101.86818
# Epoch  114  Completed! loss =  43101029108.95911
# Epoch  115  Completed! loss =  42967512163.34905
# Epoch  116  Completed! loss =  42838934806.11473
# Epoch  117  Completed! loss =  42715106373.3318
# Epoch  118  Completed! loss =  42595843686.647934
# Epoch  119  Completed! loss =  42480970756.296196
# Epoch  120  Completed! loss =  42370318496.0376
# Epoch  121  Completed! loss =  42263724449.54326
# Epoch  122  Completed! loss =  42161032527.747665
# Epoch  123  Completed! loss =  42062092756.72456
# Epoch  124  Completed! loss =  41966761035.65579
# Epoch  125  Completed! loss =  41874898904.48178
# Epoch  126  Completed! loss =  41786373320.83947
# Epoch  127  Completed! loss =  41701056445.910484
# Epoch  128  Completed! loss =  41618825438.817505
# Epoch  129  Completed! loss =  41539562259.22268
# Epoch  130  Completed! loss =  41463153477.79577
# Epoch  131  Completed! loss =  41389490094.23382
# Epoch  132  Completed! loss =  41318467362.527374
# Epoch  133  Completed! loss =  41249984623.18082
# Epoch  134  Completed! loss =  41183945142.10641
# Epoch  135  Completed! loss =  41120255955.923485
# Epoch  136  Completed! loss =  41058827723.40493
# Epoch  137  Completed! loss =  40999574582.82401
# Epoch  138  Completed! loss =  40942414014.9644
# Epoch  139  Completed! loss =  40887266711.56654
# Epoch  140  Completed! loss =  40834056448.991806
# Epoch  141  Completed! loss =  40782709966.89604
# Epoch  142  Completed! loss =  40733156851.711494
# Epoch  143  Completed! loss =  40685329424.745026
# Epoch  144  Completed! loss =  40639162634.707886
# Epoch  145  Completed! loss =  40594593954.50015
# Epoch  146  Completed! loss =  40551563282.0799
# Epoch  147  Completed! loss =  40510012845.254005
# Epoch  148  Completed! loss =  40469887110.23448
# Epoch  149  Completed! loss =  40431132693.80979
# Epoch  150  Completed! loss =  40393698278.9877
# Epoch  151  Completed! loss =  40357534533.97094
# Epoch  152  Completed! loss =  40322594034.33332
# Epoch  153  Completed! loss =  40288831188.26899
# Epoch  154  Completed! loss =  40256202164.792435
# Epoch  155  Completed! loss =  40224664824.77224
# Epoch  156  Completed! loss =  40194178654.68583
# Epoch  157  Completed! loss =  40164704702.98717
# Epoch  158  Completed! loss =  40136205518.983826
# Epoch  159  Completed! loss =  40108645094.123665
# Epoch  160  Completed! loss =  40081988805.59565
# Epoch  161  Completed! loss =  40056203362.15311
# Epoch  162  Completed! loss =  40031256752.07117
# Epoch  163  Completed! loss =  40007118193.15391
# Epoch  164  Completed! loss =  39983758084.7101
# Epoch  165  Completed! loss =  39961147961.419426
# Epoch  166  Completed! loss =  39939260449.014404
# Epoch  167  Completed! loss =  39918069221.70619
# Epoch  168  Completed! loss =  39897548961.285286
# Epoch  169  Completed! loss =  39877675317.83066
# Epoch  170  Completed! loss =  39858424871.96409
# Epoch  171  Completed! loss =  39839775098.588264
# Epoch  172  Completed! loss =  39821704332.05016
# Epoch  173  Completed! loss =  39804191732.67336
# Epoch  174  Completed! loss =  39787217254.60524
# Epoch  175  Completed! loss =  39770761614.92703
# Epoch  176  Completed! loss =  39754806263.97696
# Epoch  177  Completed! loss =  39739333356.83853
# Epoch  178  Completed! loss =  39724325725.947975
# Epoch  179  Completed! loss =  39709766854.77665
# Epoch  180  Completed! loss =  39695640852.5461
# Epoch  181  Completed! loss =  39681932429.93488
# Epoch  182  Completed! loss =  39668626875.7382
# Epoch  183  Completed! loss =  39655710034.44258
# Epoch  184  Completed! loss =  39643168284.679825
# Epoch  185  Completed! loss =  39630988518.52513
# Epoch  186  Completed! loss =  39619158121.60661
# Epoch  187  Completed! loss =  39607664953.99381
# Epoch  188  Completed! loss =  39596497331.83483
# Epoch  189  Completed! loss =  39585644009.71245
# Epoch  190  Completed! loss =  39575094163.690834
# Epoch  191  Completed! loss =  39564837375.0259
# Epoch  192  Completed! loss =  39554863614.51295
# Epoch  193  Completed! loss =  39545163227.446556
# Epoch  194  Completed! loss =  39535726919.16879
# Epoch  195  Completed! loss =  39526545741.182365
# Epoch  196  Completed! loss =  39517611077.8066
# Epoch  197  Completed! loss =  39508914633.35494
# Epoch  198  Completed! loss =  39500448419.81333
# Epoch  199  Completed! loss =  39492204744.999954
# Epoch  200  Completed! loss =  39484176201.18716
# Epoch  201  Completed! loss =  39476355654.16773
# Epoch  202  Completed! loss =  39468736232.74771
# Epoch  203  Completed! loss =  39461311318.64926
# Epoch  204  Completed! loss =  39454074536.807304
# Epoch  205  Completed! loss =  39447019746.044525
# Epoch  206  Completed! loss =  39440141030.10995
# Epoch  207  Completed! loss =  39433432689.066635
# Epoch  208  Completed! loss =  39426889231.01498
# Epoch  209  Completed! loss =  39420505364.138306
# Epoch  210  Completed! loss =  39414275989.05819
# Epoch  211  Completed! loss =  39408196191.48729
# Epoch  212  Completed! loss =  39402261235.1681
# Epoch  213  Completed! loss =  39396466555.08626
# Epoch  214  Completed! loss =  39390807750.94781
# Epoch  215  Completed! loss =  39385280580.91005
# Epoch  216  Completed! loss =  39379880955.555824
# Epoch  217  Completed! loss =  39374604932.10196
# Epoch  218  Completed! loss =  39369448708.8326
# Epoch  219  Completed! loss =  39364408619.74852
# Epoch  220  Completed! loss =  39359481129.42407
# Epoch  221  Completed! loss =  39354662828.06357
# Epoch  222  Completed! loss =  39349950426.74941
# Epoch  223  Completed! loss =  39345340752.87423
# Epoch  224  Completed! loss =  39340830745.75011
# Epoch  225  Completed! loss =  39336417452.38764
# Epoch  226  Completed! loss =  39332098023.43856
# Epoch  227  Completed! loss =  39327869709.295166
# Epoch  228  Completed! loss =  39323729856.34068
# Epoch  229  Completed! loss =  39319675903.344505
# Epoch  230  Completed! loss =  39315705377.99673
# Epoch  231  Completed! loss =  39311815893.57647
# Epoch  232  Completed! loss =  39308005145.74886
# Epoch  233  Completed! loss =  39304270909.48551
# Epoch  234  Completed! loss =  39300611036.10373
# Epoch  235  Completed! loss =  39297023450.419945
# Epoch  236  Completed! loss =  39293506148.012665
# Epoch  237  Completed! loss =  39290057192.59088
# Epoch  238  Completed! loss =  39286674713.46362
# Epoch  239  Completed! loss =  39283356903.106995
# Epoch  240  Completed! loss =  39280102014.82455
# Epoch  241  Completed! loss =  39276908360.497604
# Epoch  242  Completed! loss =  39273774308.42198
# Epoch  243  Completed! loss =  39270698281.2276
# Epoch  244  Completed! loss =  39267678753.877945
# Epoch  245  Completed! loss =  39264714251.74616
# Epoch  246  Completed! loss =  39261803348.76482
# Epoch  247  Completed! loss =  39258944665.64642
# Epoch  248  Completed! loss =  39256136868.17213
# Epoch  249  Completed! loss =  39253378665.54565
# Epoch  250  Completed! loss =  39250668808.81019
# Epoch  251  Completed! loss =  39248006089.32569
# Epoch  252  Completed! loss =  39245389337.304184
# Epoch  253  Completed! loss =  39242817420.40097
# Epoch  254  Completed! loss =  39240289242.359406
# Epoch  255  Completed! loss =  39237803741.70719
# Epoch  256  Completed! loss =  39235359890.50242
# Epoch  257  Completed! loss =  39232956693.12696
# Epoch  258  Completed! loss =  39230593185.125916
# Epoch  259  Completed! loss =  39228268432.0909
# Epoch  260  Completed! loss =  39225981528.58569
# Epoch  261  Completed! loss =  39223731597.11257
# Epoch  262  Completed! loss =  39221517787.11767
# Epoch  263  Completed! loss =  39219339274.03406
# Epoch  264  Completed! loss =  39217195258.360725
# Epoch  265  Completed! loss =  39215084964.77647
# Epoch  266  Completed! loss =  39213007641.28715
# Epoch  267  Completed! loss =  39210962558.40492
# Epoch  268  Completed! loss =  39208949008.35845
# Epoch  269  Completed! loss =  39206966304.33275
# Epoch  270  Completed! loss =  39205013779.73743
# Epoch  271  Completed! loss =  39203090787.50256
# Epoch  272  Completed! loss =  39201196699.400764
# Epoch  273  Completed! loss =  39199330905.39466
# Epoch  274  Completed! loss =  39197492813.00869
# Epoch  275  Completed! loss =  39195681846.72438
# Epoch  276  Completed! loss =  39193897447.39818
# Epoch  277  Completed! loss =  39192139071.700836
# Epoch  278  Completed! loss =  39190406191.57777
# Epoch  279  Completed! loss =  39188698293.72924
# Epoch  280  Completed! loss =  39187014879.110085
# Epoch  281  Completed! loss =  39185355462.447655
# Epoch  282  Completed! loss =  39183719571.77783
# Epoch  283  Completed! loss =  39182106747.99795
# Epoch  284  Completed! loss =  39180516544.436386
# Epoch  285  Completed! loss =  39178948526.43784
# Epoch  286  Completed! loss =  39177402270.963936
# Epoch  287  Completed! loss =  39175877366.20843
# Epoch  288  Completed! loss =  39174373411.22652
# Epoch  289  Completed! loss =  39172890015.57774
# Epoch  290  Completed! loss =  39171426798.981895
# Epoch  291  Completed! loss =  39169983390.98743
# Epoch  292  Completed! loss =  39168559430.65203
# Epoch  293  Completed! loss =  39167154566.234665
# Epoch  294  Completed! loss =  39165768454.89893
# Epoch  295  Completed! loss =  39164400762.426994
# Epoch  296  Completed! loss =  39163051162.94403
# Epoch  297  Completed! loss =  39161719338.6524
# Epoch  298  Completed! loss =  39160404979.57556
# Epoch  299  Completed! loss =  39159107783.3111
# Epoch  300  Completed! loss =  39157827454.79261
# Epoch  301  Completed! loss =  39156563706.06009
# Epoch  302  Completed! loss =  39155316256.0386
# Epoch  303  Completed! loss =  39154084830.32465
# Epoch  304  Completed! loss =  39152869160.98038
# Epoch  305  Completed! loss =  39151668986.33485
# Epoch  306  Completed! loss =  39150484050.792496
# Epoch  307  Completed! loss =  39149314104.64823
# Epoch  308  Completed! loss =  39148158903.90919
# Epoch  309  Completed! loss =  39147018210.122604
# Epoch  310  Completed! loss =  39145891790.20979
# Epoch  311  Completed! loss =  39144779416.30591
# Epoch  312  Completed! loss =  39143680865.6053
# Epoch  313  Completed! loss =  39142595920.21223
# Epoch  314  Completed! loss =  39141524366.9968
# Epoch  315  Completed! loss =  39140465997.455826
# Epoch  316  Completed! loss =  39139420607.57849
# Epoch  317  Completed! loss =  39138387997.71673
# Epoch  318  Completed! loss =  39137367972.45989
# Epoch  319  Completed! loss =  39136360340.51385
# Epoch  320  Completed! loss =  39135364914.58409
# Epoch  321  Completed! loss =  39134381511.262924
# Epoch  322  Completed! loss =  39133409950.92038
# Epoch  323  Completed! loss =  39132450057.59886
# Epoch  324  Completed! loss =  39131501658.91134
# Epoch  325  Completed! loss =  39130564585.94297
# Epoch  326  Completed! loss =  39129638673.15597
# Epoch  327  Completed! loss =  39128723758.29765
# Epoch  328  Completed! loss =  39127819682.31167
# Epoch  329  Completed! loss =  39126926289.251915
# Epoch  330  Completed! loss =  39126043426.199554
# Epoch  331  Completed! loss =  39125170943.182594
# Epoch  332  Completed! loss =  39124308693.09817
# Epoch  333  Completed! loss =  39123456531.63736
# Epoch  334  Completed! loss =  39122614317.21241
# Epoch  335  Completed! loss =  39121781910.88635
# Epoch  336  Completed! loss =  39120959176.304855
# Epoch  337  Completed! loss =  39120145979.63037
# Epoch  338  Completed! loss =  39119342189.4782
# Epoch  339  Completed! loss =  39118547676.854805
# Epoch  340  Completed! loss =  39117762315.09792
# Epoch  341  Completed! loss =  39116985979.81865
# Epoch  342  Completed! loss =  39116218548.84532
# Epoch  343  Completed! loss =  39115459902.1692
# Epoch  344  Completed! loss =  39114709921.89176
# Epoch  345  Completed! loss =  39113968492.17371
# Epoch  346  Completed! loss =  39113235499.18557
# Epoch  347  Completed! loss =  39112510831.0597
# Epoch  348  Completed! loss =  39111794377.84389
# Epoch  349  Completed! loss =  39111086031.456276
# Epoch  350  Completed! loss =  39110385685.6418
# Epoch  351  Completed! loss =  39109693235.929726
# Epoch  352  Completed! loss =  39109008579.592636
# Epoch  353  Completed! loss =  39108331615.60657
# Epoch  354  Completed! loss =  39107662244.61239
# Epoch  355  Completed! loss =  39107000368.87825
# Epoch  356  Completed! loss =  39106345892.2632
# Epoch  357  Completed! loss =  39105698720.181854
# Epoch  358  Completed! loss =  39105058759.570045
# Epoch  359  Completed! loss =  39104425918.851585
# Epoch  360  Completed! loss =  39103800107.905846
# Epoch  361  Completed! loss =  39103181238.036354
# Epoch  362  Completed! loss =  39102569221.94031
# Epoch  363  Completed! loss =  39101963973.678856
# Epoch  364  Completed! loss =  39101365408.648346
# Epoch  365  Completed! loss =  39100773443.55225
# Epoch  366  Completed! loss =  39100187996.37397
# Epoch  367  Completed! loss =  39099608986.35036
# Epoch  368  Completed! loss =  39099036333.945946
# Epoch  369  Completed! loss =  39098469960.827965
# Epoch  370  Completed! loss =  39097909789.84196
# Epoch  371  Completed! loss =  39097355744.98806
# Epoch  372  Completed! loss =  39096807751.39799
# Epoch  373  Completed! loss =  39096265735.312584
# Epoch  374  Completed! loss =  39095729624.05997
# Epoch  375  Completed! loss =  39095199346.03429
# Epoch  376  Completed! loss =  39094674830.67502
# Epoch  377  Completed! loss =  39094156008.44676
# Epoch  378  Completed! loss =  39093642810.81969
# Epoch  379  Completed! loss =  39093135170.25031
# Epoch  380  Completed! loss =  39092633020.16288
# Epoch  381  Completed! loss =  39092136294.931274
# Epoch  382  Completed! loss =  39091644929.86119
# Epoch  383  Completed! loss =  39091158861.17298
# Epoch  384  Completed! loss =  39090678025.98475
# Epoch  385  Completed! loss =  39090202362.296
# Epoch  386  Completed! loss =  39089731808.97156
# Epoch  387  Completed! loss =  39089266305.72603
# Epoch  388  Completed! loss =  39088805793.108536
# Epoch  389  Completed! loss =  39088350212.48784
# Epoch  390  Completed! loss =  39087899506.037834
# Epoch  391  Completed! loss =  39087453616.72341
# Epoch  392  Completed! loss =  39087012488.28661
# Epoch  393  Completed! loss =  39086576065.23311
# Epoch  394  Completed! loss =  39086144292.81908
# Epoch  395  Completed! loss =  39085717117.03822
# Epoch  396  Completed! loss =  39085294484.60932
# Epoch  397  Completed! loss =  39084876342.96382
# Epoch  398  Completed! loss =  39084462640.23389
# Epoch  399  Completed! loss =  39084053325.24062
# Epoch  400  Completed! loss =  39083648347.48264
# Epoch  401  Completed! loss =  39083247657.12479
# Epoch  402  Completed! loss =  39082851204.987206
# Epoch  403  Completed! loss =  39082458942.53461
# Epoch  404  Completed! loss =  39082070821.86572
# Epoch  405  Completed! loss =  39081686795.70312
# Epoch  406  Completed! loss =  39081306817.38306
# Epoch  407  Completed! loss =  39080930840.84575
# Epoch  408  Completed! loss =  39080558820.62565
# Epoch  409  Completed! loss =  39080190711.84213
# Epoch  410  Completed! loss =  39079826470.19016
# Epoch  411  Completed! loss =  39079466051.931366
# Epoch  412  Completed! loss =  39079109413.88511
# Epoch  413  Completed! loss =  39078756513.41988
# Epoch  414  Completed! loss =  39078407308.44482
# Epoch  415  Completed! loss =  39078061757.40134
# Epoch  416  Completed! loss =  39077719819.255066
# Epoch  417  Completed! loss =  39077381453.48778
# Epoch  418  Completed! loss =  39077046620.089676
# Epoch  419  Completed! loss =  39076715279.55164
# Epoch  420  Completed! loss =  39076387392.857735
# Epoch  421  Completed! loss =  39076062921.47784
# Epoch  422  Completed! loss =  39075741827.36046
# Epoch  423  Completed! loss =  39075424072.92557
# Epoch  424  Completed! loss =  39075109621.05769
# Epoch  425  Completed! loss =  39074798435.099144
# Epoch  426  Completed! loss =  39074490478.843216
# Epoch  427  Completed! loss =  39074185716.52772
# Epoch  428  Completed! loss =  39073884112.8285
# Epoch  429  Completed! loss =  39073585632.85311
# Epoch  430  Completed! loss =  39073290242.1346
# Epoch  431  Completed! loss =  39072997906.62547
# Epoch  432  Completed! loss =  39072708592.691635
# Epoch  433  Completed! loss =  39072422267.106575
# Epoch  434  Completed! loss =  39072138897.04557
# Epoch  435  Completed! loss =  39071858450.080025
# Epoch  436  Completed! loss =  39071580894.17193
# Epoch  437  Completed! loss =  39071306197.66837
# Epoch  438  Completed! loss =  39071034329.29617
# Epoch  439  Completed! loss =  39070765258.15662
# Epoch  440  Completed! loss =  39070498953.720276
# Epoch  441  Completed! loss =  39070235385.82188
# Epoch  442  Completed! loss =  39069974524.65537
# Epoch  443  Completed! loss =  39069716340.76896
# Epoch  444  Completed! loss =  39069460805.06022
# Epoch  445  Completed! loss =  39069207888.77146
# Epoch  446  Completed! loss =  39068957563.48495
# Epoch  447  Completed! loss =  39068709801.11834
# Epoch  448  Completed! loss =  39068464573.92021
# Epoch  449  Completed! loss =  39068221854.46551
# Epoch  450  Completed! loss =  39067981615.6513
# Epoch  451  Completed! loss =  39067743830.692345
# Epoch  452  Completed! loss =  39067508473.11701
# Epoch  453  Completed! loss =  39067275516.762955
# Epoch  454  Completed! loss =  39067044935.77317
# Epoch  455  Completed! loss =  39066816704.591835
# Epoch  456  Completed! loss =  39066590797.96046
# Epoch  457  Completed! loss =  39066367190.91389
# Epoch  458  Completed! loss =  39066145858.77653
# Epoch  459  Completed! loss =  39065926777.15855
# Epoch  460  Completed! loss =  39065709921.95213
# Epoch  461  Completed! loss =  39065495269.32789
# Epoch  462  Completed! loss =  39065282795.731125
# Epoch  463  Completed! loss =  39065072477.87844
# Epoch  464  Completed! loss =  39064864292.75414
# Epoch  465  Completed! loss =  39064658217.60681
# Epoch  466  Completed! loss =  39064454229.94592
# Epoch  467  Completed! loss =  39064252307.53856
# Epoch  468  Completed! loss =  39064052428.406044
# Epoch  469  Completed! loss =  39063854570.82074
# Epoch  470  Completed! loss =  39063658713.30288
# Epoch  471  Completed! loss =  39063464834.61739
# Epoch  472  Completed! loss =  39063272913.77085
# Epoch  473  Completed! loss =  39063082930.00836
# Epoch  474  Completed! loss =  39062894862.81063
# Epoch  475  Completed! loss =  39062708691.89096
# Epoch  476  Completed! loss =  39062524397.19236
# Epoch  477  Completed! loss =  39062341958.88465
# Epoch  478  Completed! loss =  39062161357.36163
# Epoch  479  Completed! loss =  39061982573.23833
# Epoch  480  Completed! loss =  39061805587.34822
# Epoch  481  Completed! loss =  39061630380.740524
# Epoch  482  Completed! loss =  39061456934.677505
# Epoch  483  Completed! loss =  39061285230.63193
# Epoch  484  Completed! loss =  39061115250.284325
# Epoch  485  Completed! loss =  39060946975.52059
# Epoch  486  Completed! loss =  39060780388.42933
# Epoch  487  Completed! loss =  39060615471.29946
# Epoch  488  Completed! loss =  39060452206.617714
# Epoch  489  Completed! loss =  39060290577.06622
# Epoch  490  Completed! loss =  39060130565.520164
# Epoch  491  Completed! loss =  39059972155.04539
# Epoch  492  Completed! loss =  39059815328.8961
# Epoch  493  Completed! loss =  39059660070.512596
# Epoch  494  Completed! loss =  39059506363.51897
# Epoch  495  Completed! loss =  39059354191.72092
# Epoch  496  Completed! loss =  39059203539.10356
# Epoch  497  Completed! loss =  39059054389.82923
# Epoch  498  Completed! loss =  39058906728.23543
# Epoch  499  Completed! loss =  39058760538.8326
# Epoch  500  Completed! loss =  39058615806.30215
# Training completed!!

# %% [markdown]
# ### **Evaluation and Visualization**
# Lets plot how loss varies with epochs

# %%
test_loss = loss(y(x_test,a,b), y_test)

print("Loss on test data = ",test_loss)

# Visualization of loss

plt.plot(range(epochs), train_loss)                   # plot loss versus epochs
plt.title("Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()
# Out:
# Loss on test data =  47314191338.81761

# %% [markdown]
# ## **Deep Learning**
# In this section We will build a simple multilayer perceptron network(**MLP**) in TensorFlow

# %%
# Lets import the required libraries
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Load Dataset**
# We will be using MNIST dataset of handwritten digits
#
# Just run the cell below to load dataset

# %%
mnist = keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print("No. of training examples = ",x_train.shape[0])
print("Size of each image in dataset = ",x_train.shape[1:])
print("No. of test examples = ",x_test.shape[0])
# Out:
# No. of training examples =  60000
# Size of each image in dataset =  (28, 28)
# No. of test examples =  10000

# %%
# Run this cell to visualize some of the images from dataset

n = 5    # = no. of images to visualize

index = np.random.choice(x_train.shape[0],5)  # choose random index
print("label: ",end="")

for i,ind in enumerate(index):
    plt.subplot(1,n,i+1)
    plt.imshow(x_train[ind],cmap="gray")
    plt.axis("off")
    print(y_train[ind],end="       ")

plt.show()
# Out:
# label: 7       1       1       3       9

# %% [markdown]
# #### Preprocess dataset
# Since we are building a MLP model the input to the model should be a vector rather than a 28 by 28 matrix.
#
# So your **First Task** is to flatten the images
#
# (Hint: use *reshape()* method of arrays...)
#
# Next, create validation dataset out of training dataset.
#
# You can use 50K images for training and 10K for validation

# %%
# Flatten the images into 1-d vectors

x_train_flatten = x_train.reshape(x_train.shape[0],28, 28)                                  # flatten the images of training set
x_test_flatten = x_test.reshape(x_test.shape[0], 28, 28)                              # flatten th eimages of test set


# Divide the training data into training and validation data....

n_validation = 10000                                        # choose number of images to be used for validation

x_validation = x_train_flatten[0:n_validation]
y_validation = y_train[0:n_validation]

x_train_flatten = x_train_flatten[n_validation:]
y_train = y_train[n_validation:]

print(x_train_flatten.shape,x_validation.shape, y_train.shape)
# Out:
# (50000, 28, 28) (10000, 28, 28) (50000,)

# %%
from tensorflow.keras.utils import to_categorical
y_train_one_hot = to_categorical(y_train, 10)
y_validation_one_hot = to_categorical(y_validation, 10)
y_test_one_hot = to_categorical(y_test, 10)

# %% [markdown]
# ### **Build a model**
# You can choose whatever architechure you want, but ensure that it is **not too deep** as that will take too much time to train and **not too shallow** as that will give very low accuracy.

# %%
model = keras.models.Sequential([
    layers.Conv2D(32, (3,3), activation='relu', input_shape=(28, 28, 1)),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(32, (3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Make a graphical representation of the model...
keras.utils.plot_model(model,show_shapes=True)
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 26, 26, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 13, 13, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 11, 11, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 5, 5, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 800)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         102,528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 113,386 (442.91 KB)
#  Trainable params: 113,386 (442.91 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### Compile and Train
# Choose an optimizer- method that minimizes loss function
#
# **adam** optimizer is one of the popular choices. You should read about these online

# %%
model.compile(optimizer="adam",loss = "categorical_crossentropy",metrics=["accuracy"])

n_epochs = 10              # set number of epochs
batch_size = 512            # you can tweak with these parametrs
history = model.fit(x_train_flatten, y_train_one_hot, validation_data=(x_validation, y_validation_one_hot), epochs=n_epochs, batch_size=batch_size)
# Out:
# Epoch 1/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 34s 331ms/step - accuracy: 0.5355 - loss: 10.3416 - val_accuracy: 0.9187 - val_loss: 0.2871
# Epoch 2/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 32s 321ms/step - accuracy: 0.9341 - loss: 0.2260 - val_accuracy: 0.9548 - val_loss: 0.1542
# Epoch 3/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 39s 305ms/step - accuracy: 0.9663 - loss: 0.1102 - val_accuracy: 0.9666 - val_loss: 0.1181
# Epoch 4/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 30s 306ms/step - accuracy: 0.9767 - loss: 0.0750 - val_accuracy: 0.9676 - val_loss: 0.1065
# Epoch 5/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 310ms/step - accuracy: 0.9827 - loss: 0.0571 - val_accuracy: 0.9723 - val_loss: 0.1009
# Epoch 6/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 311ms/step - accuracy: 0.9869 - loss: 0.0425 - val_accuracy: 0.9744 - val_loss: 0.0876
# Epoch 7/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 309ms/step - accuracy: 0.9900 - loss: 0.0310 - val_accuracy: 0.9764 - val_loss: 0.0879
# Epoch 8/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 42s 319ms/step - accuracy: 0.9924 - loss: 0.0256 - val_accuracy: 0.9780 - val_loss: 0.0827
# Epoch 9/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 317ms/step - accuracy: 0.9940 - loss: 0.0212 - val_accuracy: 0.9773 - val_loss: 0.0816
# Epoch 10/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 40s 308ms/step - accuracy: 0.9959 - loss: 0.0149 - val_accuracy: 0.9782 - val_loss: 0.0858

# %% [markdown]
# ### **Evaluate**
# Evaluate your model on test data.
#
# And Show some results

# %%
results = model.evaluate(x_test_flatten, y_test_one_hot)
print("Loss = ",results[0])
print("Accuracy = ",results[1]*100,"%")

# Plot Accuracy...
plt.plot(history.history['accuracy'], label="Training accuracy")
plt.plot(history.history['val_accuracy'], label="validation Accuracy")
plt.title("Model accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# Similarly write code to plot loss...
plt.plot(history.history['loss'], label="Training loss")
plt.plot(history.history['val_loss'], label="validation loss")
plt.title("Model loss")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9773 - loss: 0.0762
# Loss =  0.058482978492975235
# Accuracy =  98.25999736785889 %

# %% [markdown]
# Lets show our results on images from testing dataset

# %%
n = 5   # = no. of images to see predictions on

index = np.random.choice(x_test_flatten.shape[0],n)  # choose random index from test data
print("label:      ")

for i,ind in enumerate(index):
    plt.subplot(1,n,i+1)
    plt.imshow(x_test[ind], cmap="gray")             # fill code to show images from test set
    plt.axis("off")
    print(y_test[ind],end="       ")

plt.show()
print("Predicted value: ")

# Now lets print the predictions

for i,ind in enumerate(index):
    # write code to predict and print digit in image
    # Hint: the output of the model is a 10-d vector which gives probabilties
    # The digit in the image would be the class for which probability is hghest...
    image = x_test[ind].reshape(1, 28, 28,1)
    digit = np.argmax(model.predict(image,verbose=0),axis=1)
    print("      ",digit[0],end="     ")
# Out:
# label:
# 6       4       1       2       2
# Predicted value:
#        6            4            1            2            2
