# %% [markdown]
# ## **Linear Regression**
# We will use Linear regression for predicting house prices
#
# We are using a Kaggle dataset- https://www.kaggle.com/harlfoxem/housesalesprediction

# %%
# Lets import required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### **Dataset Preparation**

# %%
# Execute this cell for loading dataset in a pandas dataframe

from IPython.display import clear_output
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=16x6-8Znn2T50zFwVvKlzsdN7Jd1hpjct' -O Linear_regression_dataset

data_df = pd.read_csv("Linear_regression_dataset")
# Out:
# --2024-12-09 13:32:48--  https://docs.google.com/uc?export=download&id=16x6-8Znn2T50zFwVvKlzsdN7Jd1hpjct
# Resolving docs.google.com (docs.google.com)... 108.177.11.138, 108.177.11.113, 108.177.11.139, ...
# Connecting to docs.google.com (docs.google.com)|108.177.11.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=16x6-8Znn2T50zFwVvKlzsdN7Jd1hpjct&export=download [following]
# --2024-12-09 13:32:48--  https://drive.usercontent.google.com/download?id=16x6-8Znn2T50zFwVvKlzsdN7Jd1hpjct&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.141.132, 2607:f8b0:400c:c06::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.141.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2515206 (2.4M) [application/octet-stream]
# Saving to: ‘Linear_regression_dataset’
#
# Linear_regression_d 100%[===================>]   2.40M  --.-KB/s    in 0.02s
#
# 2024-12-09 13:32:52 (149 MB/s) - ‘Linear_regression_dataset’ saved [2515206/2515206]

# %%
# Lets have a quick Look at dataset

print("(No of rows, No of Columns) = ",data_df.shape)
data_df.head()
# Out:
# (No of rows, No of Columns) =  (21613, 21)
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# So there are **19** features (of course we will not use id as feature :) ), and 1 variable to predict(price)
#
# But note that the **date** column contain strings so first we will remove T00.. part from it and than convert it to numpy array.

# %%
data_df['date'] = data_df['date'].str.replace('T000000','')                           # Remove T000000 part from data column. Hint: search about .str.replace() method. :)

data_array = data_df.drop(['id'],axis=1).values.astype(float)                         # Create a numpy array which does not have "id" field
assert (data_array.shape == (21613,20))

data_df.head()
# Out:
#            id      date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520  20141013  221900.0         3       1.00         1180      5650
# 1  6414100192  20141209  538000.0         3       2.25         2570      7242
# 2  5631500400  20150225  180000.0         2       1.00          770     10000
# 3  2487200875  20141209  604000.0         4       3.00         1960      5000
# 4  1954400510  20150218  510000.0         3       2.00         1680      8080
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     2.0           0     0  ...      7        2170            400      1951
# 2     1.0           0     0  ...      6         770              0      1933
# 3     1.0           0     0  ...      7        1050            910      1965
# 4     1.0           0     0  ...      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# Now the next task is **normalization**.
#
# We will scale each column of dataset by x -> (x-u)/s
#
# where u is mean(x), and s is standard deviation of u

# %%
mean = np.mean(data_array,axis=0)                                 # this should be an array, each entry should be mean of a column
sd = np.std(data_array,axis=0)                                    # this should be an array, each entry should be standard deviation of a column

data_array_norm = (data_array - mean)/sd

print(data_array_norm.shape)
# Out:
# (21613, 20)

# %% [markdown]
# The last step is to make train and test dataset and to create seperate vector for price

# %%
labels = data_df['price']                                                                                                            # extract the price column from data

x_array_norm = np.delete(data_array_norm, 1, axis = 1)                                                                                                      # delete the price column from data_array_norm. Hint: use np.delete()

x_train, x_test, y_train, y_test = train_test_split(x_array_norm,labels,test_size=0.15,random_state=42,shuffle=True)    # splitting data into test and train set.

print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (18371, 19) (3242, 19) (18371,) (3242,)

# %% [markdown]
# ### **Loss and gradient descent**
# We will use mean squared error(MSE) as loss
#
# Use the gradient descent algorithm which you learned from tutorials
#
# Your task is to complete the following functions

# %%
def loss(y_pred,y_true):

  m=y_pred.shape[0]
  squared_error=np.sum((y_pred-y_true)**2)
  mse = squared_error/m                     # fill code here

  return mse

# %%
def y(x,a,b):

  m,n = x.shape
  y_pred = np.dot(x,a) + b                   # fill code here

  assert(y_pred.shape == (m,))
  return y_pred

# %%
def gradient(x,a,b,y_true):

  m,n = x.shape
  yp = y(x,a,b)

  da = (2/m)*np.dot(x.T,yp-y_true)              # write code to calculate derivative of loss with respect to a
  db = (2/m)*np.sum(yp-y_true)                  # write code to calculate derivative of loss with respect to b

  assert(da.shape ==(n,))
  return (da,db)

# %%
def gradient_descent(x,y_true,learning_rate=0.01,epochs = 10):

  m,n = x.shape
  loss_mse = []                                 # initialize empty list to store loss
  a = np.ones(n)                                       # initialize a- weights and b- bias
  b = 0

  for i in range(epochs):
    # calculate derivative using gradient() function
    # apply gradient descent now to update a and b
    da=gradient(x,a,b,y_true)[0]
    db=gradient(x,a,b,y_true)[1]
    a-=learning_rate*da
    b-=learning_rate*db
    y_pred = y(x,a,b)
    l_mse = loss(y_pred,y_true)                                # calculate loss at this point
    loss_mse.append(l_mse)

    print("Epoch ",i+1," Completed!","loss = ",l_mse)

  print("Training completed!!")

  assert(a.shape==(n,))

  return (loss_mse,a,b)

# %% [markdown]
# ### **Training**

# %%
epochs = 1000              # tweak this!!!
learn_rate = 0.01          # choose learning rate wisely otherwise loss may diverge!!

train_loss,a,b = gradient_descent(x_train,y_train,learn_rate,epochs)
# Out:
# Epoch  1  Completed! loss =  397182252347.69806
# Epoch  2  Completed! loss =  375661914086.5015
# Epoch  3  Completed! loss =  356345658886.54816
# Epoch  4  Completed! loss =  338889395101.00275
# Epoch  5  Completed! loss =  323012470673.93225
# Epoch  6  Completed! loss =  308485402011.24335
# Epoch  7  Completed! loss =  295120009144.39465
# Epoch  8  Completed! loss =  282761483276.98126
# Epoch  9  Completed! loss =  271282006283.6468
# Epoch  10  Completed! loss =  260575616760.06223
# Epoch  11  Completed! loss =  250554077444.34695
# Epoch  12  Completed! loss =  241143547167.50748
# Epoch  13  Completed! loss =  232281899289.35236
# Epoch  14  Completed! loss =  223916559719.7685
# Epoch  15  Completed! loss =  216002762624.37262
# Epoch  16  Completed! loss =  208502141981.16885
# Epoch  17  Completed! loss =  201381593264.3195
# Epoch  18  Completed! loss =  194612352463.6627
# Epoch  19  Completed! loss =  188169250031.16687
# Epoch  20  Completed! loss =  182030105681.30286
# Epoch  21  Completed! loss =  176175236665.20847
# Epoch  22  Completed! loss =  170587057512.66293
# Epoch  23  Completed! loss =  165249753551.44437
# Epoch  24  Completed! loss =  160149013979.42444
# Epoch  25  Completed! loss =  155271813048.3558
# Epoch  26  Completed! loss =  150606230154.25848
# Epoch  27  Completed! loss =  146141301425.576
# Epoch  28  Completed! loss =  141866896843.52972
# Epoch  29  Completed! loss =  137773618088.90756
# Epoch  30  Completed! loss =  133852713241.73238
# Epoch  31  Completed! loss =  130096005209.68472
# Epoch  32  Completed! loss =  126495831363.7975
# Epoch  33  Completed! loss =  123044992344.67462
# Epoch  34  Completed! loss =  119736708392.51431
# Epoch  35  Completed! loss =  116564581868.15355
# Epoch  36  Completed! loss =  113522564885.14496
# Epoch  37  Completed! loss =  110604931176.53827
# Epoch  38  Completed! loss =  107806251484.20125
# Epoch  39  Completed! loss =  105121371890.92383
# Epoch  40  Completed! loss =  102545394622.42044
# Epoch  41  Completed! loss =  100073660932.67432
# Epoch  42  Completed! loss =  97701735755.86418
# Epoch  43  Completed! loss =  95425393864.6051
# Epoch  44  Completed! loss =  93240607320.00723
# Epoch  45  Completed! loss =  91143534036.19539
# Epoch  46  Completed! loss =  89130507312.10748
# Epoch  47  Completed! loss =  87198026207.9525
# Epoch  48  Completed! loss =  85342746663.73468
# Epoch  49  Completed! loss =  83561473273.61621
# Epoch  50  Completed! loss =  81851151643.2945
# Epoch  51  Completed! loss =  80208861268.57439
# Epoch  52  Completed! loss =  78631808882.37996
# Epoch  53  Completed! loss =  77117322224.93625
# Epoch  54  Completed! loss =  75662844198.05489
# Epoch  55  Completed! loss =  74265927369.62143
# Epoch  56  Completed! loss =  72924228798.69139
# Epoch  57  Completed! loss =  71635505155.21883
# Epoch  58  Completed! loss =  70397608111.48793
# Epoch  59  Completed! loss =  69208479984.89764
# Epoch  60  Completed! loss =  68066149613.94247
# Epoch  61  Completed! loss =  66968728451.11075
# Epoch  62  Completed! loss =  65914406858.033424
# Epoch  63  Completed! loss =  64901450589.61143
# Epoch  64  Completed! loss =  63928197455.060394
# Epoch  65  Completed! loss =  62993054144.87037
# Epoch  66  Completed! loss =  62094493213.60695
# Epoch  67  Completed! loss =  61231050209.30094
# Epoch  68  Completed! loss =  60401320940.90091
# Epoch  69  Completed! loss =  59603958875.91234
# Epoch  70  Completed! loss =  58837672660.92744
# Epoch  71  Completed! loss =  58101223758.27262
# Epoch  72  Completed! loss =  57393424192.47179
# Epoch  73  Completed! loss =  56713134400.652275
# Epoch  74  Completed! loss =  56059261181.4087
# Epoch  75  Completed! loss =  55430755736.99523
# Epoch  76  Completed! loss =  54826611804.042274
# Epoch  77  Completed! loss =  54245863868.29197
# Epoch  78  Completed! loss =  53687585459.12143
# Epoch  79  Completed! loss =  53150887519.87675
# Epoch  80  Completed! loss =  52634916850.27457
# Epoch  81  Completed! loss =  52138854617.34587
# Epoch  82  Completed! loss =  51661914931.59762
# Epoch  83  Completed! loss =  51203343485.25571
# Epoch  84  Completed! loss =  50762416249.627205
# Epoch  85  Completed! loss =  50338438228.78221
# Epoch  86  Completed! loss =  49930742266.90815
# Epoch  87  Completed! loss =  49538687906.830956
# Epoch  88  Completed! loss =  49161660297.33074
# Epoch  89  Completed! loss =  48799069147.00408
# Epoch  90  Completed! loss =  48450347722.541954
# Epoch  91  Completed! loss =  48114951889.40177
# Epoch  92  Completed! loss =  47792359192.955444
# Epoch  93  Completed! loss =  47482067978.29183
# Epoch  94  Completed! loss =  47183596546.94345
# Epoch  95  Completed! loss =  46896482348.89317
# Epoch  96  Completed! loss =  46620281208.29748
# Epoch  97  Completed! loss =  46354566581.43916
# Epoch  98  Completed! loss =  46098928845.49473
# Epoch  99  Completed! loss =  45852974616.76944
# Epoch  100  Completed! loss =  45616326097.117485
# Epoch  101  Completed! loss =  45388620447.325554
# Epoch  102  Completed! loss =  45169509186.295395
# Epoch  103  Completed! loss =  44958657614.91586
# Epoch  104  Completed! loss =  44755744263.56605
# Epoch  105  Completed! loss =  44560460362.24023
# Epoch  106  Completed! loss =  44372509332.33175
# Epoch  107  Completed! loss =  44191606299.156746
# Epoch  108  Completed! loss =  44017477624.34043
# Epoch  109  Completed! loss =  43849860457.2282
# Epoch  110  Completed! loss =  43688502304.52162
# Epoch  111  Completed! loss =  43533160617.374825
# Epoch  112  Completed! loss =  43383602395.22102
# Epoch  113  Completed! loss =  43239603805.63108
# Epoch  114  Completed! loss =  43100949819.53696
# Epoch  115  Completed! loss =  42967433861.181755
# Epoch  116  Completed! loss =  42838857472.18652
# Epoch  117  Completed! loss =  42715029989.149826
# Epoch  118  Completed! loss =  42595768234.22208
# Epoch  119  Completed! loss =  42480896218.119995
# Epoch  120  Completed! loss =  42370244855.0702
# Epoch  121  Completed! loss =  42263651689.19229
# Epoch  122  Completed! loss =  42160960631.85313
# Epoch  123  Completed! loss =  42062021709.54343
# Epoch  124  Completed! loss =  41966690821.84751
# Epoch  125  Completed! loss =  41874829509.094406
# Epoch  126  Completed! loss =  41786304729.296585
# Epoch  127  Completed! loss =  41700988643.99862
# Epoch  128  Completed! loss =  41618758412.67434
# Epoch  129  Completed! loss =  41539495995.32566
# Epoch  130  Completed! loss =  41463087962.95128
# Epoch  131  Completed! loss =  41389425315.566895
# Epoch  132  Completed! loss =  41318403307.47183
# Epoch  133  Completed! loss =  41249921279.46982
# Epoch  134  Completed! loss =  41183882497.76343
# Epoch  135  Completed! loss =  41120193999.25368
# Epoch  136  Completed! loss =  41058766442.98686
# Epoch  137  Completed! loss =  40999513967.501625
# Epoch  138  Completed! loss =  40942354053.83951
# Epoch  139  Completed! loss =  40887207393.99135
# Epoch  140  Completed! loss =  40833997764.56193
# Epoch  141  Completed! loss =  40782651905.4437
# Epoch  142  Completed! loss =  40733099403.29899
# Epoch  143  Completed! loss =  40685272579.65836
# Epoch  144  Completed! loss =  40639106383.45074
# Epoch  145  Completed! loss =  40594538287.787994
# Epoch  146  Completed! loss =  40551508190.834305
# Epoch  147  Completed! loss =  40509958320.59717
# Epoch  148  Completed! loss =  40469833143.48393
# Epoch  149  Completed! loss =  40431079276.47327
# Epoch  150  Completed! loss =  40393645402.758156
# Epoch  151  Completed! loss =  40357482190.721756
# Epoch  152  Completed! loss =  40322542216.11366
# Epoch  153  Completed! loss =  40288779887.29923
# Epoch  154  Completed! loss =  40256151373.45985
# Epoch  155  Completed! loss =  40224614535.62669
# Epoch  156  Completed! loss =  40194128860.43569
# Epoch  157  Completed! loss =  40164655396.495285
# Epoch  158  Completed! loss =  40136156693.26362
# Epoch  159  Completed! loss =  40108596742.33538
# Epoch  160  Completed! loss =  40081940921.04268
# Epoch  161  Completed! loss =  40056155938.27838
# Epoch  162  Completed! loss =  40031209782.45368
# Epoch  163  Completed! loss =  40007071671.50543
# Epoch  164  Completed! loss =  39983712004.87177
# Epoch  165  Completed! loss =  39961102317.35861
# Epoch  166  Completed! loss =  39939215234.82158
# Epoch  167  Completed! loss =  39918024431.59192
# Epoch  168  Completed! loss =  39897504589.57722
# Epoch  169  Completed! loss =  39877631358.97071
# Epoch  170  Completed! loss =  39858381320.50563
# Epoch  171  Completed! loss =  39839731949.1934
# Epoch  172  Completed! loss =  39821661579.48701
# Epoch  173  Completed! loss =  39804149371.81356
# Epoch  174  Completed! loss =  39787175280.42135
# Epoch  175  Completed! loss =  39770720022.49012
# Epoch  176  Completed! loss =  39754765048.45423
# Epoch  177  Completed! loss =  39739292513.490906
# Epoch  178  Completed! loss =  39724285250.12787
# Epoch  179  Completed! loss =  39709726741.92579
# Epoch  180  Completed! loss =  39695601098.193306
# Epoch  181  Completed! loss =  39681893029.69399
# Epoch  182  Completed! loss =  39668587825.306
# Epoch  183  Completed! loss =  39655671329.596825
# Epoch  184  Completed! loss =  39643129921.27725
# Epoch  185  Completed! loss =  39630950492.49958
# Epoch  186  Completed! loss =  39619120428.96716
# Epoch  187  Completed! loss =  39607627590.823
# Epoch  188  Completed! loss =  39596460294.28686
# Epoch  189  Completed! loss =  39585607294.01148
# Epoch  190  Completed! loss =  39575057766.12933
# Epoch  191  Completed! loss =  39564801291.96297
# Epoch  192  Completed! loss =  39554827842.37273
# Epoch  193  Completed! loss =  39545127762.71673
# Epoch  194  Completed! loss =  39535691758.399025
# Epoch  195  Completed! loss =  39526510880.98285
# Epoch  196  Completed! loss =  39517576514.846596
# Epoch  197  Completed! loss =  39508880364.36143
# Epoch  198  Completed! loss =  39500414441.5696
# Epoch  199  Completed! loss =  39492171054.34427
# Epoch  200  Completed! loss =  39484142795.01148
# Epoch  201  Completed! loss =  39476322529.41649
# Epoch  202  Completed! loss =  39468703386.4165
# Epoch  203  Completed! loss =  39461278747.783676
# Epoch  204  Completed! loss =  39454042238.50177
# Epoch  205  Completed! loss =  39446987717.44117
# Epoch  206  Completed! loss =  39440109268.39746
# Epoch  207  Completed! loss =  39433401191.479195
# Epoch  208  Completed! loss =  39426857994.83124
# Epoch  209  Completed! loss =  39420474386.68031
# Epoch  210  Completed! loss =  39414245267.69039
# Epoch  211  Completed! loss =  39408165723.61559
# Epoch  212  Completed! loss =  39402231018.23888
# Epoch  213  Completed! loss =  39396436586.58544
# Epoch  214  Completed! loss =  39390778028.40001
# Epoch  215  Completed! loss =  39385251101.87763
# Epoch  216  Completed! loss =  39379851717.6381
# Epoch  217  Completed! loss =  39374575932.9343
# Epoch  218  Completed! loss =  39369419946.085686
# Epoch  219  Completed! loss =  39364380091.12747
# Epoch  220  Completed! loss =  39359452832.66774
# Epoch  221  Completed! loss =  39354634760.94377
# Epoch  222  Completed! loss =  39349922587.070175
# Epoch  223  Completed! loss =  39345313138.471146
# Epoch  224  Completed! loss =  39340803354.489525
# Epoch  225  Completed! loss =  39336390282.1661
# Epoch  226  Completed! loss =  39332071072.182045
# Epoch  227  Completed! loss =  39327842974.95855
# Epoch  228  Completed! loss =  39323703336.907036
# Epoch  229  Completed! loss =  39319649596.82452
# Epoch  230  Completed! loss =  39315679282.428085
# Epoch  231  Completed! loss =  39311790007.023346
# Epoch  232  Completed! loss =  39307979466.30126
# Epoch  233  Completed! loss =  39304245435.25877
# Epoch  234  Completed! loss =  39300585765.23802
# Epoch  235  Completed! loss =  39296998381.07971
# Epoch  236  Completed! loss =  39293481278.3861
# Epoch  237  Completed! loss =  39290032520.889465
# Epoch  238  Completed! loss =  39286650237.921646
# Epoch  239  Completed! loss =  39283332621.981064
# Epoch  240  Completed! loss =  39280077926.39316
# Epoch  241  Completed! loss =  39276884463.060684
# Epoch  242  Completed! loss =  39273750600.30047
# Epoch  243  Completed! loss =  39270674760.76298
# Epoch  244  Completed! loss =  39267655419.43191
# Epoch  245  Completed! loss =  39264691101.700165
# Epoch  246  Completed! loss =  39261780381.51969
# Epoch  247  Completed! loss =  39258921879.62202
# Epoch  248  Completed! loss =  39256114261.80693
# Epoch  249  Completed! loss =  39253356237.29641
# Epoch  250  Completed! loss =  39250646557.15158
# Epoch  251  Completed! loss =  39247984012.749985
# Epoch  252  Completed! loss =  39245367434.320915
# Epoch  253  Completed! loss =  39242795689.53658
# Epoch  254  Completed! loss =  39240267682.15696
# Epoch  255  Completed! loss =  39237782350.7261
# Epoch  256  Completed! loss =  39235338667.31804
# Epoch  257  Completed! loss =  39232935636.3304
# Epoch  258  Completed! loss =  39230572293.32371
# Epoch  259  Completed! loss =  39228247703.90474
# Epoch  260  Completed! loss =  39225960962.65215
# Epoch  261  Completed! loss =  39223711192.08286
# Epoch  262  Completed! loss =  39221497541.657364
# Epoch  263  Completed! loss =  39219319186.82283
# Epoch  264  Completed! loss =  39217175328.09213
# Epoch  265  Completed! loss =  39215065190.157715
# Epoch  266  Completed! loss =  39212988021.03883
# Epoch  267  Completed! loss =  39210943091.26082
# Epoch  268  Completed! loss =  39208929693.0653
# Epoch  269  Completed! loss =  39206947139.65002
# Epoch  270  Completed! loss =  39204994764.43714
# Epoch  271  Completed! loss =  39203071920.36907
# Epoch  272  Completed! loss =  39201177979.23055
# Epoch  273  Completed! loss =  39199312330.99613
# Epoch  274  Completed! loss =  39197474383.202
# Epoch  275  Completed! loss =  39195663560.34127
# Epoch  276  Completed! loss =  39193879303.28176
# Epoch  277  Completed! loss =  39192121068.70544
# Epoch  278  Completed! loss =  39190388328.568726
# Epoch  279  Completed! loss =  39188680569.58281
# Epoch  280  Completed! loss =  39186997292.713165
# Epoch  281  Completed! loss =  39185338012.69774
# Epoch  282  Completed! loss =  39183702257.582756
# Epoch  283  Completed! loss =  39182089568.27584
# Epoch  284  Completed! loss =  39180499498.115425
# Epoch  285  Completed! loss =  39178931612.456184
# Epoch  286  Completed! loss =  39177385488.2695
# Epoch  287  Completed! loss =  39175860713.758804
# Epoch  288  Completed! loss =  39174356887.98885
# Epoch  289  Completed! loss =  39172873620.528564
# Epoch  290  Completed! loss =  39171410531.10698
# Epoch  291  Completed! loss =  39169967249.28174
# Epoch  292  Completed! loss =  39168543414.1195
# Epoch  293  Completed! loss =  39167138673.88814
# Epoch  294  Completed! loss =  39165752685.76005
# Epoch  295  Completed! loss =  39164385115.52606
# Epoch  296  Completed! loss =  39163035637.31988
# Epoch  297  Completed! loss =  39161703933.35232
# Epoch  298  Completed! loss =  39160389693.655174
# Epoch  299  Completed! loss =  39159092615.83427
# Epoch  300  Completed! loss =  39157812404.8313
# Epoch  301  Completed! loss =  39156548772.69432
# Epoch  302  Completed! loss =  39155301438.35626
# Epoch  303  Completed! loss =  39154070127.421524
# Epoch  304  Completed! loss =  39152854571.959946
# Epoch  305  Completed! loss =  39151654510.30824
# Epoch  306  Completed! loss =  39150469686.87838
# Epoch  307  Completed! loss =  39149299851.97276
# Epoch  308  Completed! loss =  39148144761.60588
# Epoch  309  Completed! loss =  39147004177.33225
# Epoch  310  Completed! loss =  39145877866.08041
# Epoch  311  Completed! loss =  39144765599.992615
# Epoch  312  Completed! loss =  39143667156.27028
# Epoch  313  Completed! loss =  39142582317.02461
# Epoch  314  Completed! loss =  39141510869.1326
# Epoch  315  Completed! loss =  39140452604.09786
# Epoch  316  Completed! loss =  39139407317.91635
# Epoch  317  Completed! loss =  39138374810.946625
# Epoch  318  Completed! loss =  39137354887.78466
# Epoch  319  Completed! loss =  39136347357.142815
# Epoch  320  Completed! loss =  39135352031.73307
# Epoch  321  Completed! loss =  39134368728.15407
# Epoch  322  Completed! loss =  39133397266.78219
# Epoch  323  Completed! loss =  39132437471.66608
# Epoch  324  Completed! loss =  39131489170.424904
# Epoch  325  Completed! loss =  39130552194.149925
# Epoch  326  Completed! loss =  39129626377.30942
# Epoch  327  Completed! loss =  39128711557.65674
# Epoch  328  Completed! loss =  39127807576.141426
# Epoch  329  Completed! loss =  39126914276.823296
# Epoch  330  Completed! loss =  39126031506.78932
# Epoch  331  Completed! loss =  39125159116.073296
# Epoch  332  Completed! loss =  39124296957.57804
# Epoch  333  Completed! loss =  39123444887.000305
# Epoch  334  Completed! loss =  39122602762.75792
# Epoch  335  Completed! loss =  39121770445.91949
# Epoch  336  Completed! loss =  39120947800.13617
# Epoch  337  Completed! loss =  39120134691.57584
# Epoch  338  Completed! loss =  39119330988.85924
# Epoch  339  Completed! loss =  39118536562.99813
# Epoch  340  Completed! loss =  39117751287.33554
# Epoch  341  Completed! loss =  39116975037.48784
# Epoch  342  Completed! loss =  39116207691.28856
# Epoch  343  Completed! loss =  39115449128.73409
# Epoch  344  Completed! loss =  39114699231.93102
# Epoch  345  Completed! loss =  39113957885.045135
# Epoch  346  Completed! loss =  39113224974.25193
# Epoch  347  Completed! loss =  39112500387.68876
# Epoch  348  Completed! loss =  39111784015.40832
# Epoch  349  Completed! loss =  39111075749.33367
# Epoch  350  Completed! loss =  39110375483.21455
# Epoch  351  Completed! loss =  39109683112.58501
# Epoch  352  Completed! loss =  39108998534.7224
# Epoch  353  Completed! loss =  39108321648.60748
# Epoch  354  Completed! loss =  39107652354.88579
# Epoch  355  Completed! loss =  39106990555.83009
# Epoch  356  Completed! loss =  39106336155.30406
# Epoch  357  Completed! loss =  39105689058.72682
# Epoch  358  Completed! loss =  39105049173.038765
# Epoch  359  Completed! loss =  39104416406.668144
# Epoch  360  Completed! loss =  39103790669.498795
# Epoch  361  Completed! loss =  39103171872.83864
# Epoch  362  Completed! loss =  39102559929.38924
# Epoch  363  Completed! loss =  39101954753.21607
# Epoch  364  Completed! loss =  39101356259.71978
# Epoch  365  Completed! loss =  39100764365.608086
# Epoch  366  Completed! loss =  39100178988.86863
# Epoch  367  Completed! loss =  39099600048.74242
# Epoch  368  Completed! loss =  39099027465.69818
# Epoch  369  Completed! loss =  39098461161.40725
# Epoch  370  Completed! loss =  39097901058.71925
# Epoch  371  Completed! loss =  39097347081.638374
# Epoch  372  Completed! loss =  39096799155.30036
# Epoch  373  Completed! loss =  39096257205.95003
# Epoch  374  Completed! loss =  39095721160.91949
# Epoch  375  Completed! loss =  39095190948.60677
# Epoch  376  Completed! loss =  39094666498.45527
# Epoch  377  Completed! loss =  39094147740.93345
# Epoch  378  Completed! loss =  39093634607.51528
# Epoch  379  Completed! loss =  39093127030.66109
# Epoch  380  Completed! loss =  39092624943.79894
# Epoch  381  Completed! loss =  39092128281.306404
# Epoch  382  Completed! loss =  39091636978.49292
# Epoch  383  Completed! loss =  39091150971.5825
# Epoch  384  Completed! loss =  39090670197.696915
# Epoch  385  Completed! loss =  39090194594.83927
# Epoch  386  Completed! loss =  39089724101.87801
# Epoch  387  Completed! loss =  39089258658.53133
# Epoch  388  Completed! loss =  39088798205.351845
# Epoch  389  Completed! loss =  39088342683.71185
# Epoch  390  Completed! loss =  39087892035.788734
# Epoch  391  Completed! loss =  39087446204.55085
# Epoch  392  Completed! loss =  39087005133.74365
# Epoch  393  Completed! loss =  39086568767.87623
# Epoch  394  Completed! loss =  39086137052.20811
# Epoch  395  Completed! loss =  39085709932.7364
# Epoch  396  Completed! loss =  39085287356.18317
# Epoch  397  Completed! loss =  39084869269.983185
# Epoch  398  Completed! loss =  39084455622.271866
# Epoch  399  Completed! loss =  39084046361.87359
# Epoch  400  Completed! loss =  39083641438.290184
# Epoch  401  Completed! loss =  39083240801.6897
# Epoch  402  Completed! loss =  39082844402.895454
# Epoch  403  Completed! loss =  39082452193.37529
# Epoch  404  Completed! loss =  39082064125.23112
# Epoch  405  Completed! loss =  39081680151.18857
# Epoch  406  Completed! loss =  39081300224.587
# Epoch  407  Completed! loss =  39080924299.36966
# Epoch  408  Completed! loss =  39080552330.07407
# Epoch  409  Completed! loss =  39080184271.82259
# Epoch  410  Completed! loss =  39079820080.313194
# Epoch  411  Completed! loss =  39079459711.81045
# Epoch  412  Completed! loss =  39079103123.136696
# Epoch  413  Completed! loss =  39078750271.66331
# Epoch  414  Completed! loss =  39078401115.30233
# Epoch  415  Completed! loss =  39078055612.49808
# Epoch  416  Completed! loss =  39077713722.218994
# Epoch  417  Completed! loss =  39077375403.94974
# Epoch  418  Completed! loss =  39077040617.68329
# Epoch  419  Completed! loss =  39076709323.91332
# Epoch  420  Completed! loss =  39076381483.62666
# Epoch  421  Completed! loss =  39076057058.29597
# Epoch  422  Completed! loss =  39075736009.87242
# Epoch  423  Completed! loss =  39075418300.778755
# Epoch  424  Completed! loss =  39075103893.90217
# Epoch  425  Completed! loss =  39074792752.58762
# Epoch  426  Completed! loss =  39074484840.63107
# Epoch  427  Completed! loss =  39074180122.27296
# Epoch  428  Completed! loss =  39073878562.19171
# Epoch  429  Completed! loss =  39073580125.497475
# Epoch  430  Completed! loss =  39073284777.72591
# Epoch  431  Completed! loss =  39072992484.832
# Epoch  432  Completed! loss =  39072703213.18423
# Epoch  433  Completed! loss =  39072416929.55858
# Epoch  434  Completed! loss =  39072133601.13282
# Epoch  435  Completed! loss =  39071853195.48083
# Epoch  436  Completed! loss =  39071575680.56703
# Epoch  437  Completed! loss =  39071301024.74099
# Epoch  438  Completed! loss =  39071029196.73191
# Epoch  439  Completed! loss =  39070760165.643486
# Epoch  440  Completed! loss =  39070493900.94867
# Epoch  441  Completed! loss =  39070230372.48456
# Epoch  442  Completed! loss =  39069969550.44745
# Epoch  443  Completed! loss =  39069711405.38783
# Epoch  444  Completed! loss =  39069455908.20565
# Epoch  445  Completed! loss =  39069203030.14547
# Epoch  446  Completed! loss =  39068952742.79184
# Epoch  447  Completed! loss =  39068705018.0647
# Epoch  448  Completed! loss =  39068459828.214806
# Epoch  449  Completed! loss =  39068217145.81939
# Epoch  450  Completed! loss =  39067976943.77769
# Epoch  451  Completed! loss =  39067739195.3067
# Epoch  452  Completed! loss =  39067503873.936905
# Epoch  453  Completed! loss =  39067270953.50817
# Epoch  454  Completed! loss =  39067040408.16559
# Epoch  455  Completed! loss =  39066812212.35551
# Epoch  456  Completed! loss =  39066586340.82151
# Epoch  457  Completed! loss =  39066362768.60055
# Epoch  458  Completed! loss =  39066141471.01912
# Epoch  459  Completed! loss =  39065922423.68944
# Epoch  460  Completed! loss =  39065705602.50575
# Epoch  461  Completed! loss =  39065490983.64067
# Epoch  462  Completed! loss =  39065278543.54155
# Epoch  463  Completed! loss =  39065068258.92698
# Epoch  464  Completed! loss =  39064860106.78325
# Epoch  465  Completed! loss =  39064654064.36091
# Epoch  466  Completed! loss =  39064450109.1714
# Epoch  467  Completed! loss =  39064248218.98374
# Epoch  468  Completed! loss =  39064048371.82118
# Epoch  469  Completed! loss =  39063850545.95801
# Epoch  470  Completed! loss =  39063654719.91632
# Epoch  471  Completed! loss =  39063460872.462975
# Epoch  472  Completed! loss =  39063268982.60637
# Epoch  473  Completed! loss =  39063079029.59351
# Epoch  474  Completed! loss =  39062890992.90691
# Epoch  475  Completed! loss =  39062704852.261734
# Epoch  476  Completed! loss =  39062520587.60277
# Epoch  477  Completed! loss =  39062338179.10163
# Epoch  478  Completed! loss =  39062157607.15395
# Epoch  479  Completed! loss =  39061978852.3765
# Epoch  480  Completed! loss =  39061801895.60453
# Epoch  481  Completed! loss =  39061626717.888985
# Epoch  482  Completed! loss =  39061453300.49387
# Epoch  483  Completed! loss =  39061281624.89367
# Epoch  484  Completed! loss =  39061111672.77064
# Epoch  485  Completed! loss =  39060943426.012344
# Epoch  486  Completed! loss =  39060776866.70908
# Epoch  487  Completed! loss =  39060611977.15145
# Epoch  488  Completed! loss =  39060448739.82782
# Epoch  489  Completed! loss =  39060287137.421974
# Epoch  490  Completed! loss =  39060127152.81073
# Epoch  491  Completed! loss =  39059968769.06155
# Epoch  492  Completed! loss =  39059811969.43024
# Epoch  493  Completed! loss =  39059656737.35868
# Epoch  494  Completed! loss =  39059503056.47257
# Epoch  495  Completed! loss =  39059350910.57917
# Epoch  496  Completed! loss =  39059200283.66517
# Epoch  497  Completed! loss =  39059051159.89443
# Epoch  498  Completed! loss =  39058903523.605995
# Epoch  499  Completed! loss =  39058757359.31183
# Epoch  500  Completed! loss =  39058612651.69486
# Epoch  501  Completed! loss =  39058469385.60687
# Epoch  502  Completed! loss =  39058327546.06652
# Epoch  503  Completed! loss =  39058187118.25731
# Epoch  504  Completed! loss =  39058048087.52564
# Epoch  505  Completed! loss =  39057910439.37888
# Epoch  506  Completed! loss =  39057774159.48345
# Epoch  507  Completed! loss =  39057639233.6629
# Epoch  508  Completed! loss =  39057505647.8961
# Epoch  509  Completed! loss =  39057373388.31538
# Epoch  510  Completed! loss =  39057242441.20467
# Epoch  511  Completed! loss =  39057112792.99783
# Epoch  512  Completed! loss =  39056984430.276726
# Epoch  513  Completed! loss =  39056857339.769646
# Epoch  514  Completed! loss =  39056731508.34943
# Epoch  515  Completed! loss =  39056606923.03191
# Epoch  516  Completed! loss =  39056483570.97413
# Epoch  517  Completed! loss =  39056361439.47274
# Epoch  518  Completed! loss =  39056240515.96237
# Epoch  519  Completed! loss =  39056120788.014
# Epoch  520  Completed! loss =  39056002243.33337
# Epoch  521  Completed! loss =  39055884869.759415
# Epoch  522  Completed! loss =  39055768655.262726
# Epoch  523  Completed! loss =  39055653587.944016
# Epoch  524  Completed! loss =  39055539656.03257
# Epoch  525  Completed! loss =  39055426847.88486
# Epoch  526  Completed! loss =  39055315151.98292
# Epoch  527  Completed! loss =  39055204556.933044
# Epoch  528  Completed! loss =  39055095051.46425
# Epoch  529  Completed! loss =  39054986624.42692
# Epoch  530  Completed! loss =  39054879264.79134
# Epoch  531  Completed! loss =  39054772961.64642
# Epoch  532  Completed! loss =  39054667704.198235
# Epoch  533  Completed! loss =  39054563481.768715
# Epoch  534  Completed! loss =  39054460283.79433
# Epoch  535  Completed! loss =  39054358099.824745
# Epoch  536  Completed! loss =  39054256919.52159
# Epoch  537  Completed! loss =  39054156732.65709
# Epoch  538  Completed! loss =  39054057529.112854
# Epoch  539  Completed! loss =  39053959298.87864
# Epoch  540  Completed! loss =  39053862032.051094
# Epoch  541  Completed! loss =  39053765718.83253
# Epoch  542  Completed! loss =  39053670349.52975
# Epoch  543  Completed! loss =  39053575914.55286
# Epoch  544  Completed! loss =  39053482404.41407
# Epoch  545  Completed! loss =  39053389809.726555
# Epoch  546  Completed! loss =  39053298121.20331
# Epoch  547  Completed! loss =  39053207329.65603
# Epoch  548  Completed! loss =  39053117425.99396
# Epoch  549  Completed! loss =  39053028401.22285
# Epoch  550  Completed! loss =  39052940246.443794
# Epoch  551  Completed! loss =  39052852952.85225
# Epoch  552  Completed! loss =  39052766511.73687
# Epoch  553  Completed! loss =  39052680914.47853
# Epoch  554  Completed! loss =  39052596152.549286
# Epoch  555  Completed! loss =  39052512217.5113
# Epoch  556  Completed! loss =  39052429101.015884
# Epoch  557  Completed! loss =  39052346794.802475
# Epoch  558  Completed! loss =  39052265290.69767
# Epoch  559  Completed! loss =  39052184580.6142
# Epoch  560  Completed! loss =  39052104656.55003
# Epoch  561  Completed! loss =  39052025510.58737
# Epoch  562  Completed! loss =  39051947134.89176
# Epoch  563  Completed! loss =  39051869521.71112
# Epoch  564  Completed! loss =  39051792663.37483
# Epoch  565  Completed! loss =  39051716552.29283
# Epoch  566  Completed! loss =  39051641180.95476
# Epoch  567  Completed! loss =  39051566541.929016
# Epoch  568  Completed! loss =  39051492627.86191
# Epoch  569  Completed! loss =  39051419431.47681
# Epoch  570  Completed! loss =  39051346945.57325
# Epoch  571  Completed! loss =  39051275163.026146
# Epoch  572  Completed! loss =  39051204076.78493
# Epoch  573  Completed! loss =  39051133679.87268
# Epoch  574  Completed! loss =  39051063965.38543
# Epoch  575  Completed! loss =  39050994926.49121
# Epoch  576  Completed! loss =  39050926556.4294
# Epoch  577  Completed! loss =  39050858848.509834
# Epoch  578  Completed! loss =  39050791796.11208
# Epoch  579  Completed! loss =  39050725392.684685
# Epoch  580  Completed! loss =  39050659631.74434
# Epoch  581  Completed! loss =  39050594506.87522
# Epoch  582  Completed! loss =  39050530011.72823
# Epoch  583  Completed! loss =  39050466140.02021
# Epoch  584  Completed! loss =  39050402885.53328
# Epoch  585  Completed! loss =  39050340242.11409
# Epoch  586  Completed! loss =  39050278203.67314
# Epoch  587  Completed! loss =  39050216764.18407
# Epoch  588  Completed! loss =  39050155917.68294
# Epoch  589  Completed! loss =  39050095658.26762
# Epoch  590  Completed! loss =  39050035980.09704
# Epoch  591  Completed! loss =  39049976877.39059
# Epoch  592  Completed! loss =  39049918344.427414
# Epoch  593  Completed! loss =  39049860375.54579
# Epoch  594  Completed! loss =  39049802965.14245
# Epoch  595  Completed! loss =  39049746107.672
# Epoch  596  Completed! loss =  39049689797.64626
# Epoch  597  Completed! loss =  39049634029.63364
# Epoch  598  Completed! loss =  39049578798.25852
# Epoch  599  Completed! loss =  39049524098.20068
# Epoch  600  Completed! loss =  39049469924.19467
# Epoch  601  Completed! loss =  39049416271.02923
# Epoch  602  Completed! loss =  39049363133.54669
# Epoch  603  Completed! loss =  39049310506.6424
# Epoch  604  Completed! loss =  39049258385.2642
# Epoch  605  Completed! loss =  39049206764.41177
# Epoch  606  Completed! loss =  39049155639.13611
# Epoch  607  Completed! loss =  39049105004.53903
# Epoch  608  Completed! loss =  39049054855.77255
# Epoch  609  Completed! loss =  39049005188.03837
# Epoch  610  Completed! loss =  39048955996.58736
# Epoch  611  Completed! loss =  39048907276.71899
# Epoch  612  Completed! loss =  39048859023.78086
# Epoch  613  Completed! loss =  39048811233.16815
# Epoch  614  Completed! loss =  39048763900.32312
# Epoch  615  Completed! loss =  39048717020.734566
# Epoch  616  Completed! loss =  39048670589.93743
# Epoch  617  Completed! loss =  39048624603.51218
# Epoch  618  Completed! loss =  39048579057.0844
# Epoch  619  Completed! loss =  39048533946.32428
# Epoch  620  Completed! loss =  39048489266.946175
# Epoch  621  Completed! loss =  39048445014.70807
# Epoch  622  Completed! loss =  39048401185.41117
# Epoch  623  Completed! loss =  39048357774.89944
# Epoch  624  Completed! loss =  39048314779.05908
# Epoch  625  Completed! loss =  39048272193.81819
# Epoch  626  Completed! loss =  39048230015.14622
# Epoch  627  Completed! loss =  39048188239.053566
# Epoch  628  Completed! loss =  39048146861.59117
# Epoch  629  Completed! loss =  39048105878.85006
# Epoch  630  Completed! loss =  39048065286.96091
# Epoch  631  Completed! loss =  39048025082.09364
# Epoch  632  Completed! loss =  39047985260.457
# Epoch  633  Completed! loss =  39047945818.29816
# Epoch  634  Completed! loss =  39047906751.90227
# Epoch  635  Completed! loss =  39047868057.59213
# Epoch  636  Completed! loss =  39047829731.727715
# Epoch  637  Completed! loss =  39047791770.70586
# Epoch  638  Completed! loss =  39047754170.959755
# Epoch  639  Completed! loss =  39047716928.95872
# Epoch  640  Completed! loss =  39047680041.20768
# Epoch  641  Completed! loss =  39047643504.24685
# Epoch  642  Completed! loss =  39047607314.6514
# Epoch  643  Completed! loss =  39047571469.03102
# Epoch  644  Completed! loss =  39047535964.029594
# Epoch  645  Completed! loss =  39047500796.324814
# Epoch  646  Completed! loss =  39047465962.627884
# Epoch  647  Completed! loss =  39047431459.6831
# Epoch  648  Completed! loss =  39047397284.267525
# Epoch  649  Completed! loss =  39047363433.19067
# Epoch  650  Completed! loss =  39047329903.29413
# Epoch  651  Completed! loss =  39047296691.451225
# Epoch  652  Completed! loss =  39047263794.56676
# Epoch  653  Completed! loss =  39047231209.576546
# Epoch  654  Completed! loss =  39047198933.44725
# Epoch  655  Completed! loss =  39047166963.1759
# Epoch  656  Completed! loss =  39047135295.78973
# Epoch  657  Completed! loss =  39047103928.34571
# Epoch  658  Completed! loss =  39047072857.93039
# Epoch  659  Completed! loss =  39047042081.65943
# Epoch  660  Completed! loss =  39047011596.67745
# Epoch  661  Completed! loss =  39046981400.157646
# Epoch  662  Completed! loss =  39046951489.30145
# Epoch  663  Completed! loss =  39046921861.33837
# Epoch  664  Completed! loss =  39046892513.52556
# Epoch  665  Completed! loss =  39046863443.14761
# Epoch  666  Completed! loss =  39046834647.51627
# Epoch  667  Completed! loss =  39046806123.97009
# Epoch  668  Completed! loss =  39046777869.87424
# Epoch  669  Completed! loss =  39046749882.620155
# Epoch  670  Completed! loss =  39046722159.625305
# Epoch  671  Completed! loss =  39046694698.33291
# Epoch  672  Completed! loss =  39046667496.211685
# Epoch  673  Completed! loss =  39046640550.75558
# Epoch  674  Completed! loss =  39046613859.483475
# Epoch  675  Completed! loss =  39046587419.93898
# Epoch  676  Completed! loss =  39046561229.690155
# Epoch  677  Completed! loss =  39046535286.329254
# Epoch  678  Completed! loss =  39046509587.47246
# Epoch  679  Completed! loss =  39046484130.75968
# Epoch  680  Completed! loss =  39046458913.85426
# Epoch  681  Completed! loss =  39046433934.44278
# Epoch  682  Completed! loss =  39046409190.23478
# Epoch  683  Completed! loss =  39046384678.962524
# Epoch  684  Completed! loss =  39046360398.38081
# Epoch  685  Completed! loss =  39046336346.266685
# Epoch  686  Completed! loss =  39046312520.41926
# Epoch  687  Completed! loss =  39046288918.65944
# Epoch  688  Completed! loss =  39046265538.829735
# Epoch  689  Completed! loss =  39046242378.79404
# Epoch  690  Completed! loss =  39046219436.43736
# Epoch  691  Completed! loss =  39046196709.66568
# Epoch  692  Completed! loss =  39046174196.40568
# Epoch  693  Completed! loss =  39046151894.60455
# Epoch  694  Completed! loss =  39046129802.22978
# Epoch  695  Completed! loss =  39046107917.26897
# Epoch  696  Completed! loss =  39046086237.72956
# Epoch  697  Completed! loss =  39046064761.6387
# Epoch  698  Completed! loss =  39046043487.04302
# Epoch  699  Completed! loss =  39046022412.008415
# Epoch  700  Completed! loss =  39046001534.61988
# Epoch  701  Completed! loss =  39045980852.981285
# Epoch  702  Completed! loss =  39045960365.21522
# Epoch  703  Completed! loss =  39045940069.46273
# Epoch  704  Completed! loss =  39045919963.88324
# Epoch  705  Completed! loss =  39045900046.65425
# Epoch  706  Completed! loss =  39045880315.97122
# Epoch  707  Completed! loss =  39045860770.04742
# Epoch  708  Completed! loss =  39045841407.11361
# Epoch  709  Completed! loss =  39045822225.41803
# Epoch  710  Completed! loss =  39045803223.22612
# Epoch  711  Completed! loss =  39045784398.820366
# Epoch  712  Completed! loss =  39045765750.50011
# Epoch  713  Completed! loss =  39045747276.58146
# Epoch  714  Completed! loss =  39045728975.39699
# Epoch  715  Completed! loss =  39045710845.2957
# Epoch  716  Completed! loss =  39045692884.64277
# Epoch  717  Completed! loss =  39045675091.81938
# Epoch  718  Completed! loss =  39045657465.222664
# Epoch  719  Completed! loss =  39045640003.26541
# Epoch  720  Completed! loss =  39045622704.37598
# Epoch  721  Completed! loss =  39045605566.99812
# Epoch  722  Completed! loss =  39045588589.59085
# Epoch  723  Completed! loss =  39045571770.62826
# Epoch  724  Completed! loss =  39045555108.599365
# Epoch  725  Completed! loss =  39045538602.00797
# Epoch  726  Completed! loss =  39045522249.37254
# Epoch  727  Completed! loss =  39045506049.226006
# Epoch  728  Completed! loss =  39045490000.115616
# Epoch  729  Completed! loss =  39045474100.60287
# Epoch  730  Completed! loss =  39045458349.263275
# Epoch  731  Completed! loss =  39045442744.68629
# Epoch  732  Completed! loss =  39045427285.475105
# Epoch  733  Completed! loss =  39045411970.24656
# Epoch  734  Completed! loss =  39045396797.631
# Epoch  735  Completed! loss =  39045381766.27211
# Epoch  736  Completed! loss =  39045366874.82684
# Epoch  737  Completed! loss =  39045352121.96518
# Epoch  738  Completed! loss =  39045337506.370125
# Epoch  739  Completed! loss =  39045323026.73746
# Epoch  740  Completed! loss =  39045308681.77572
# Epoch  741  Completed! loss =  39045294470.20598
# Epoch  742  Completed! loss =  39045280390.76176
# Epoch  743  Completed! loss =  39045266442.188934
# Epoch  744  Completed! loss =  39045252623.245544
# Epoch  745  Completed! loss =  39045238932.70173
# Epoch  746  Completed! loss =  39045225369.339584
# Epoch  747  Completed! loss =  39045211931.95303
# Epoch  748  Completed! loss =  39045198619.34771
# Epoch  749  Completed! loss =  39045185430.34087
# Epoch  750  Completed! loss =  39045172363.761246
# Epoch  751  Completed! loss =  39045159418.448944
# Epoch  752  Completed! loss =  39045146593.255295
# Epoch  753  Completed! loss =  39045133887.04283
# Epoch  754  Completed! loss =  39045121298.68507
# Epoch  755  Completed! loss =  39045108827.06646
# Epoch  756  Completed! loss =  39045096471.082306
# Epoch  757  Completed! loss =  39045084229.63854
# Epoch  758  Completed! loss =  39045072101.65177
# Epoch  759  Completed! loss =  39045060086.04905
# Epoch  760  Completed! loss =  39045048181.76784
# Epoch  761  Completed! loss =  39045036387.75586
# Epoch  762  Completed! loss =  39045024702.971054
# Epoch  763  Completed! loss =  39045013126.38144
# Epoch  764  Completed! loss =  39045001656.96496
# Epoch  765  Completed! loss =  39044990293.70952
# Epoch  766  Completed! loss =  39044979035.61276
# Epoch  767  Completed! loss =  39044967881.68202
# Epoch  768  Completed! loss =  39044956830.93421
# Epoch  769  Completed! loss =  39044945882.39577
# Epoch  770  Completed! loss =  39044935035.1025
# Epoch  771  Completed! loss =  39044924288.099556
# Epoch  772  Completed! loss =  39044913640.44126
# Epoch  773  Completed! loss =  39044903091.19108
# Epoch  774  Completed! loss =  39044892639.421524
# Epoch  775  Completed! loss =  39044882284.21401
# Epoch  776  Completed! loss =  39044872024.65887
# Epoch  777  Completed! loss =  39044861859.85514
# Epoch  778  Completed! loss =  39044851788.91056
# Epoch  779  Completed! loss =  39044841810.94149
# Epoch  780  Completed! loss =  39044831925.072754
# Epoch  781  Completed! loss =  39044822130.43763
# Epoch  782  Completed! loss =  39044812426.17774
# Epoch  783  Completed! loss =  39044802811.44295
# Epoch  784  Completed! loss =  39044793285.39129
# Epoch  785  Completed! loss =  39044783847.18891
# Epoch  786  Completed! loss =  39044774496.00999
# Epoch  787  Completed! loss =  39044765231.03662
# Epoch  788  Completed! loss =  39044756051.45876
# Epoch  789  Completed! loss =  39044746956.474144
# Epoch  790  Completed! loss =  39044737945.288216
# Epoch  791  Completed! loss =  39044729017.11405
# Epoch  792  Completed! loss =  39044720171.17228
# Epoch  793  Completed! loss =  39044711406.69101
# Epoch  794  Completed! loss =  39044702722.90573
# Epoch  795  Completed! loss =  39044694119.059326
# Epoch  796  Completed! loss =  39044685594.40188
# Epoch  797  Completed! loss =  39044677148.19068
# Epoch  798  Completed! loss =  39044668779.69015
# Epoch  799  Completed! loss =  39044660488.17174
# Epoch  800  Completed! loss =  39044652272.9139
# Epoch  801  Completed! loss =  39044644133.201965
# Epoch  802  Completed! loss =  39044636068.32814
# Epoch  803  Completed! loss =  39044628077.59139
# Epoch  804  Completed! loss =  39044620160.29739
# Epoch  805  Completed! loss =  39044612315.75846
# Epoch  806  Completed! loss =  39044604543.29351
# Epoch  807  Completed! loss =  39044596842.22794
# Epoch  808  Completed! loss =  39044589211.8936
# Epoch  809  Completed! loss =  39044581651.62874
# Epoch  810  Completed! loss =  39044574160.77794
# Epoch  811  Completed! loss =  39044566738.69202
# Epoch  812  Completed! loss =  39044559384.72801
# Epoch  813  Completed! loss =  39044552098.249084
# Epoch  814  Completed! loss =  39044544878.624504
# Epoch  815  Completed! loss =  39044537725.22952
# Epoch  816  Completed! loss =  39044530637.44538
# Epoch  817  Completed! loss =  39044523614.6592
# Epoch  818  Completed! loss =  39044516656.263985
# Epoch  819  Completed! loss =  39044509761.65847
# Epoch  820  Completed! loss =  39044502930.247185
# Epoch  821  Completed! loss =  39044496161.44027
# Epoch  822  Completed! loss =  39044489454.65354
# Epoch  823  Completed! loss =  39044482809.30835
# Epoch  824  Completed! loss =  39044476224.83157
# Epoch  825  Completed! loss =  39044469700.65553
# Epoch  826  Completed! loss =  39044463236.21795
# Epoch  827  Completed! loss =  39044456830.96191
# Epoch  828  Completed! loss =  39044450484.3358
# Epoch  829  Completed! loss =  39044444195.79325
# Epoch  830  Completed! loss =  39044437964.79306
# Epoch  831  Completed! loss =  39044431790.79923
# Epoch  832  Completed! loss =  39044425673.28081
# Epoch  833  Completed! loss =  39044419611.71191
# Epoch  834  Completed! loss =  39044413605.571625
# Epoch  835  Completed! loss =  39044407654.34403
# Epoch  836  Completed! loss =  39044401757.51808
# Epoch  837  Completed! loss =  39044395914.58758
# Epoch  838  Completed! loss =  39044390125.051125
# Epoch  839  Completed! loss =  39044384388.41212
# Epoch  840  Completed! loss =  39044378704.17861
# Epoch  841  Completed! loss =  39044373071.86338
# Epoch  842  Completed! loss =  39044367490.98377
# Epoch  843  Completed! loss =  39044361961.06176
# Epoch  844  Completed! loss =  39044356481.62381
# Epoch  845  Completed! loss =  39044351052.2009
# Epoch  846  Completed! loss =  39044345672.32842
# Epoch  847  Completed! loss =  39044340341.5462
# Epoch  848  Completed! loss =  39044335059.39843
# Epoch  849  Completed! loss =  39044329825.43357
# Epoch  850  Completed! loss =  39044324639.2044
# Epoch  851  Completed! loss =  39044319500.26791
# Epoch  852  Completed! loss =  39044314408.185295
# Epoch  853  Completed! loss =  39044309362.52187
# Epoch  854  Completed! loss =  39044304362.84713
# Epoch  855  Completed! loss =  39044299408.73458
# Epoch  856  Completed! loss =  39044294499.761765
# Epoch  857  Completed! loss =  39044289635.51025
# Epoch  858  Completed! loss =  39044284815.56554
# Epoch  859  Completed! loss =  39044280039.51703
# Epoch  860  Completed! loss =  39044275306.95806
# Epoch  861  Completed! loss =  39044270617.48575
# Epoch  862  Completed! loss =  39044265970.70104
# Epoch  863  Completed! loss =  39044261366.208664
# Epoch  864  Completed! loss =  39044256803.61704
# Epoch  865  Completed! loss =  39044252282.53832
# Epoch  866  Completed! loss =  39044247802.5883
# Epoch  867  Completed! loss =  39044243363.38641
# Epoch  868  Completed! loss =  39044238964.55565
# Epoch  869  Completed! loss =  39044234605.7226
# Epoch  870  Completed! loss =  39044230286.517334
# Epoch  871  Completed! loss =  39044226006.573425
# Epoch  872  Completed! loss =  39044221765.52791
# Epoch  873  Completed! loss =  39044217563.02122
# Epoch  874  Completed! loss =  39044213398.69719
# Epoch  875  Completed! loss =  39044209272.20302
# Epoch  876  Completed! loss =  39044205183.18919
# Epoch  877  Completed! loss =  39044201131.30953
# Epoch  878  Completed! loss =  39044197116.22108
# Epoch  879  Completed! loss =  39044193137.58411
# Epoch  880  Completed! loss =  39044189195.062126
# Epoch  881  Completed! loss =  39044185288.32175
# Epoch  882  Completed! loss =  39044181417.03277
# Epoch  883  Completed! loss =  39044177580.868065
# Epoch  884  Completed! loss =  39044173779.50361
# Epoch  885  Completed! loss =  39044170012.61836
# Epoch  886  Completed! loss =  39044166279.89439
# Epoch  887  Completed! loss =  39044162581.01668
# Epoch  888  Completed! loss =  39044158915.673195
# Epoch  889  Completed! loss =  39044155283.554825
# Epoch  890  Completed! loss =  39044151684.355385
# Epoch  891  Completed! loss =  39044148117.77153
# Epoch  892  Completed! loss =  39044144583.50278
# Epoch  893  Completed! loss =  39044141081.25148
# Epoch  894  Completed! loss =  39044137610.72274
# Epoch  895  Completed! loss =  39044134171.62448
# Epoch  896  Completed! loss =  39044130763.66731
# Epoch  897  Completed! loss =  39044127386.564606
# Epoch  898  Completed! loss =  39044124040.03238
# Epoch  899  Completed! loss =  39044120723.78933
# Epoch  900  Completed! loss =  39044117437.55676
# Epoch  901  Completed! loss =  39044114181.05867
# Epoch  902  Completed! loss =  39044110954.021545
# Epoch  903  Completed! loss =  39044107756.174484
# Epoch  904  Completed! loss =  39044104587.249115
# Epoch  905  Completed! loss =  39044101446.97957
# Epoch  906  Completed! loss =  39044098335.102455
# Epoch  907  Completed! loss =  39044095251.3569
# Epoch  908  Completed! loss =  39044092195.4844
# Epoch  909  Completed! loss =  39044089167.2289
# Epoch  910  Completed! loss =  39044086166.33678
# Epoch  911  Completed! loss =  39044083192.55671
# Epoch  912  Completed! loss =  39044080245.63976
# Epoch  913  Completed! loss =  39044077325.339355
# Epoch  914  Completed! loss =  39044074431.41114
# Epoch  915  Completed! loss =  39044071563.61314
# Epoch  916  Completed! loss =  39044068721.70554
# Epoch  917  Completed! loss =  39044065905.45084
# Epoch  918  Completed! loss =  39044063114.61375
# Epoch  919  Completed! loss =  39044060348.96113
# Epoch  920  Completed! loss =  39044057608.26207
# Epoch  921  Completed! loss =  39044054892.28777
# Epoch  922  Completed! loss =  39044052200.811615
# Epoch  923  Completed! loss =  39044049533.60905
# Epoch  924  Completed! loss =  39044046890.457634
# Epoch  925  Completed! loss =  39044044271.13703
# Epoch  926  Completed! loss =  39044041675.428925
# Epoch  927  Completed! loss =  39044039103.11703
# Epoch  928  Completed! loss =  39044036553.9871
# Epoch  929  Completed! loss =  39044034027.82687
# Epoch  930  Completed! loss =  39044031524.42606
# Epoch  931  Completed! loss =  39044029043.57636
# Epoch  932  Completed! loss =  39044026585.071365
# Epoch  933  Completed! loss =  39044024148.70662
# Epoch  934  Completed! loss =  39044021734.27957
# Epoch  935  Completed! loss =  39044019341.58955
# Epoch  936  Completed! loss =  39044016970.43772
# Epoch  937  Completed! loss =  39044014620.62717
# Epoch  938  Completed! loss =  39044012291.96274
# Epoch  939  Completed! loss =  39044009984.251144
# Epoch  940  Completed! loss =  39044007697.300865
# Epoch  941  Completed! loss =  39044005430.92216
# Epoch  942  Completed! loss =  39044003184.92708
# Epoch  943  Completed! loss =  39044000959.129395
# Epoch  944  Completed! loss =  39043998753.34461
# Epoch  945  Completed! loss =  39043996567.38998
# Epoch  946  Completed! loss =  39043994401.08439
# Epoch  947  Completed! loss =  39043992254.24845
# Epoch  948  Completed! loss =  39043990126.70445
# Epoch  949  Completed! loss =  39043988018.276306
# Epoch  950  Completed! loss =  39043985928.78956
# Epoch  951  Completed! loss =  39043983858.0714
# Epoch  952  Completed! loss =  39043981805.950584
# Epoch  953  Completed! loss =  39043979772.25751
# Epoch  954  Completed! loss =  39043977756.82409
# Epoch  955  Completed! loss =  39043975759.483826
# Epoch  956  Completed! loss =  39043973780.07178
# Epoch  957  Completed! loss =  39043971818.42449
# Epoch  958  Completed! loss =  39043969874.38008
# Epoch  959  Completed! loss =  39043967947.778114
# Epoch  960  Completed! loss =  39043966038.45966
# Epoch  961  Completed! loss =  39043964146.26729
# Epoch  962  Completed! loss =  39043962271.045
# Epoch  963  Completed! loss =  39043960412.63822
# Epoch  964  Completed! loss =  39043958570.893845
# Epoch  965  Completed! loss =  39043956745.66017
# Epoch  966  Completed! loss =  39043954936.7869
# Epoch  967  Completed! loss =  39043953144.125145
# Epoch  968  Completed! loss =  39043951367.52734
# Epoch  969  Completed! loss =  39043949606.84735
# Epoch  970  Completed! loss =  39043947861.94036
# Epoch  971  Completed! loss =  39043946132.66288
# Epoch  972  Completed! loss =  39043944418.87279
# Epoch  973  Completed! loss =  39043942720.42923
# Epoch  974  Completed! loss =  39043941037.192696
# Epoch  975  Completed! loss =  39043939369.024925
# Epoch  976  Completed! loss =  39043937715.78898
# Epoch  977  Completed! loss =  39043936077.34914
# Epoch  978  Completed! loss =  39043934453.57098
# Epoch  979  Completed! loss =  39043932844.32128
# Epoch  980  Completed! loss =  39043931249.46808
# Epoch  981  Completed! loss =  39043929668.88063
# Epoch  982  Completed! loss =  39043928102.42938
# Epoch  983  Completed! loss =  39043926549.985985
# Epoch  984  Completed! loss =  39043925011.42326
# Epoch  985  Completed! loss =  39043923486.615234
# Epoch  986  Completed! loss =  39043921975.43706
# Epoch  987  Completed! loss =  39043920477.76507
# Epoch  988  Completed! loss =  39043918993.47671
# Epoch  989  Completed! loss =  39043917522.4506
# Epoch  990  Completed! loss =  39043916064.56642
# Epoch  991  Completed! loss =  39043914619.70502
# Epoch  992  Completed! loss =  39043913187.74829
# Epoch  993  Completed! loss =  39043911768.57925
# Epoch  994  Completed! loss =  39043910362.08198
# Epoch  995  Completed! loss =  39043908968.14164
# Epoch  996  Completed! loss =  39043907586.64442
# Epoch  997  Completed! loss =  39043906217.4776
# Epoch  998  Completed! loss =  39043904860.52946
# Epoch  999  Completed! loss =  39043903515.68932
# Epoch  1000  Completed! loss =  39043902182.847534
# Training completed!!

# %% [markdown]
# ### **Evaluation and Visualization**
# Lets plot how loss varies with epochs

# %%
print(y_test.shape,x_test.shape,a.shape,b.shape)

y_pred=y(x_test,a,b)

test_loss = loss(y_pred, y_test)

print("Loss on test data = ",test_loss)

# Visualization of loss
x_axis=np.ones(epochs)
for i in range(epochs):
  x_axis[i]=i+1
plt.plot(x_axis, train_loss)                   # plot loss versus epochs
plt.title("Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()
# Out:
# (3242,) (3242, 19) (19,) ()
# Loss on test data =  47281527195.576004

# %% [markdown]
# ## **Deep Learning**
# In this section We will build a simple multilayer perceptron network(**MLP**) in TensorFlow

# %%
# Lets import the required libraries
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Load Dataset**
# We will be using MNIST dataset of handwritten digits
#
# Just run the cell below to load dataset

# %%
mnist = keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print("No. of training examples = ",x_train.shape[0])
print("Size of each image in dataset = ",x_train.shape[1:])
print("No. of test examples = ",x_test.shape[0])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# No. of training examples =  60000
# Size of each image in dataset =  (28, 28)
# No. of test examples =  10000

# %%
# Run this cell to visualize some of the images from dataset

n = 5    # = no. of images to visualize

index = np.random.choice(x_train.shape[0],5)  # choose random index
print("label: ",end="")

for i,ind in enumerate(index):
    plt.subplot(1,n,i+1)
    plt.imshow(x_train[ind],cmap="gray")
    plt.axis("off")
    print(y_train[ind],end="       ")

plt.show()
# Out:
# label: 4       1       5       6       2

# %% [markdown]
# #### Preprocess dataset
# Since we are building a MLP model the input to the model should be a vector rather than a 28 by 28 matrix.
#
# So your **First Task** is to flatten the images
#
# (Hint: use *reshape()* method of arrays...)
#
# Next, create validation dataset out of training dataset.
#
# You can use 50K images for training and 10K for validation

# %%
# Flatten the images into 1-d vectors

x_train_flatten = x_train.reshape(x_train.shape[0],28,28)                                       # flatten the images of training set
x_test_flatten = x_test.reshape(x_test.shape[0],28,28)                                        # flatten th eimages of test set


# Divide the training data into training and validation data....

n_validation = 10000                                        # choose number of images to be used for validation

x_validation = x_train_flatten[:n_validation]
y_validation = y_train[:n_validation]

x_train_flatten = x_train_flatten[n_validation:]
y_train = y_train[n_validation:]
x_train_flatten.shape,y_train.shape
# Out:
# ((50000, 28, 28), (50000,))

# %%
from tensorflow.keras.utils import to_categorical
y_train_one_hot = to_categorical(y_train, 10)
y_test_one_hot = to_categorical(y_test, 10)
y_validation_one_hot = to_categorical(y_validation, 10)

# %% [markdown]
# ### **Build a model**
# You can choose whatever architechure you want, but ensure that it is **not too deep** as that will take too much time to train and **not too shallow** as that will give very low accuracy.

# %%
model = keras.models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28,28, 1)),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Make a graphical representation of the model...
keras.utils.plot_model(model,show_shapes=True)
model.summary
# Out:
# <bound method Model.summary of <Sequential name=sequential_1, built=True>>

# %% [markdown]
# #### Compile and Train
# Choose an optimizer- method that minimizes loss function
#
# **adam** optimizer is one of the popular choices. You should read about these online

# %%
model.compile(optimizer="adam",loss = "categorical_crossentropy",metrics=["accuracy"])

n_epochs = 30              # set number of epochs
batch_size = 512            # you can tweak with these parametrs
history = model.fit(x_train_flatten,y_train_one_hot,epochs=n_epochs,batch_size=batch_size,validation_data=(x_validation,y_validation_one_hot))
# Out:
# Epoch 1/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 395ms/step - accuracy: 0.5138 - loss: 5.1328 - val_accuracy: 0.9190 - val_loss: 0.2939
# Epoch 2/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 38s 366ms/step - accuracy: 0.9316 - loss: 0.2354 - val_accuracy: 0.9544 - val_loss: 0.1664
# Epoch 3/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 40s 356ms/step - accuracy: 0.9592 - loss: 0.1373 - val_accuracy: 0.9632 - val_loss: 0.1309
# Epoch 4/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 38s 383ms/step - accuracy: 0.9718 - loss: 0.0928 - val_accuracy: 0.9681 - val_loss: 0.1122
# Epoch 5/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 38s 352ms/step - accuracy: 0.9782 - loss: 0.0723 - val_accuracy: 0.9687 - val_loss: 0.1105
# Epoch 6/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 42s 360ms/step - accuracy: 0.9813 - loss: 0.0600 - val_accuracy: 0.9743 - val_loss: 0.0913
# Epoch 7/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 43s 374ms/step - accuracy: 0.9853 - loss: 0.0477 - val_accuracy: 0.9756 - val_loss: 0.0871
# Epoch 8/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 35s 354ms/step - accuracy: 0.9878 - loss: 0.0374 - val_accuracy: 0.9767 - val_loss: 0.0879
# Epoch 9/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 43s 370ms/step - accuracy: 0.9898 - loss: 0.0320 - val_accuracy: 0.9778 - val_loss: 0.0819
# Epoch 10/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 40s 359ms/step - accuracy: 0.9906 - loss: 0.0288 - val_accuracy: 0.9781 - val_loss: 0.0866
# Epoch 11/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 356ms/step - accuracy: 0.9929 - loss: 0.0229 - val_accuracy: 0.9783 - val_loss: 0.0802
# Epoch 12/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 35s 357ms/step - accuracy: 0.9933 - loss: 0.0205 - val_accuracy: 0.9795 - val_loss: 0.0791
# Epoch 13/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 36s 365ms/step - accuracy: 0.9945 - loss: 0.0173 - val_accuracy: 0.9816 - val_loss: 0.0721
# Epoch 14/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 39s 351ms/step - accuracy: 0.9959 - loss: 0.0131 - val_accuracy: 0.9816 - val_loss: 0.0739
# Epoch 15/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 355ms/step - accuracy: 0.9960 - loss: 0.0128 - val_accuracy: 0.9813 - val_loss: 0.0804
# Epoch 16/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 353ms/step - accuracy: 0.9973 - loss: 0.0095 - val_accuracy: 0.9809 - val_loss: 0.0813
# Epoch 17/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 43s 372ms/step - accuracy: 0.9975 - loss: 0.0088 - val_accuracy: 0.9830 - val_loss: 0.0735
# Epoch 18/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 39s 350ms/step - accuracy: 0.9978 - loss: 0.0068 - val_accuracy: 0.9832 - val_loss: 0.0793
# Epoch 19/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 36s 371ms/step - accuracy: 0.9981 - loss: 0.0070 - val_accuracy: 0.9838 - val_loss: 0.0769
# Epoch 20/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 39s 353ms/step - accuracy: 0.9982 - loss: 0.0062 - val_accuracy: 0.9826 - val_loss: 0.0829
# Epoch 21/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 355ms/step - accuracy: 0.9987 - loss: 0.0046 - val_accuracy: 0.9833 - val_loss: 0.0879
# Epoch 22/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 35s 356ms/step - accuracy: 0.9994 - loss: 0.0035 - val_accuracy: 0.9842 - val_loss: 0.0790
# Epoch 23/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 42s 364ms/step - accuracy: 0.9996 - loss: 0.0023 - val_accuracy: 0.9825 - val_loss: 0.0874
# Epoch 24/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 361ms/step - accuracy: 0.9991 - loss: 0.0033 - val_accuracy: 0.9823 - val_loss: 0.0899
# Epoch 25/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 43s 375ms/step - accuracy: 0.9987 - loss: 0.0045 - val_accuracy: 0.9816 - val_loss: 0.0880
# Epoch 26/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 39s 357ms/step - accuracy: 0.9977 - loss: 0.0069 - val_accuracy: 0.9809 - val_loss: 0.0969
# Epoch 27/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 37s 377ms/step - accuracy: 0.9966 - loss: 0.0105 - val_accuracy: 0.9825 - val_loss: 0.0848
# Epoch 28/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 39s 354ms/step - accuracy: 0.9982 - loss: 0.0048 - val_accuracy: 0.9817 - val_loss: 0.0920
# Epoch 29/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 354ms/step - accuracy: 0.9957 - loss: 0.0116 - val_accuracy: 0.9832 - val_loss: 0.1030
# Epoch 30/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 42s 365ms/step - accuracy: 0.9967 - loss: 0.0099 - val_accuracy: 0.9811 - val_loss: 0.1030

# %% [markdown]
# ### **Evaluate**
# Evaluate your model on test data.
#
# And Show some results

# %%
results = model.evaluate(x_test_flatten,y_test_one_hot)
print("Loss = ",results[0])
print("Accuracy = ",results[1]*100,"%")

# Plot Accuracy...
plt.plot(history.history['accuracy'], label="Training accuracy")
plt.plot(history.history['val_accuracy'], label="validation Accuracy")
plt.title("Model accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# Similarly write code to plot loss...
plt.plot(history.history['loss'], label="Training Loss")
plt.plot(history.history['val_loss'], label="Validation Loss")
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9785 - loss: 0.0996
# Loss =  0.08093585819005966
# Accuracy =  98.25000166893005 %

# %% [markdown]
# Lets show our results on images from testing dataset

# %%
n = 5   # = no. of images to see predictions on

index = np.random.choice(range(len(x_test)), size=n, replace=False)  # choose random index from test data
print("label: ")

for i,ind in enumerate(index):
    plt.subplot(1,n,i+1)
    plt.imshow(x_test[ind],cmap="gray")             # fill code to show images from test set
    plt.axis("off")
    print(y_test[ind],end="       ")

plt.show()
print("Predicted value: ")

# Now lets print the predictions

for i,ind in enumerate(index):
    # write code to predict and print digit in image
    # Hint: the output of the model is a 10-d vector which gives probabilties
    # The digit in the image would be the class for which probability is hghest...
    image = x_test[ind].reshape(1, 28, 28,1)
    digit = np.argmax(model.predict(image,verbose=0),axis=1)
    print(digit,end="      ")
# Out:
# label:
# 0       0       2       5       4
# Predicted value:
# [0]      [0]      [2]      [5]      [4]
