# %% [markdown]
# ## **Linear Regression**
# We will use Linear regression for predicting house prices
#
# We are using a Kaggle dataset- https://www.kaggle.com/harlfoxem/housesalesprediction

# %%
# Lets import required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### **Dataset Preparation**

# %%
# Execute this cell for loading dataset in a pandas dataframe

from IPython.display import clear_output
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=16x6-8Znn2T50zFwVvKlzsdN7Jd1hpjct' -O Linear_regression_dataset

data_df = pd.read_csv("Linear_regression_dataset")
# Out:
# --2024-12-08 18:22:48--  https://docs.google.com/uc?export=download&id=16x6-8Znn2T50zFwVvKlzsdN7Jd1hpjct
# Resolving docs.google.com (docs.google.com)... 142.251.2.101, 142.251.2.139, 142.251.2.113, ...
# Connecting to docs.google.com (docs.google.com)|142.251.2.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=16x6-8Znn2T50zFwVvKlzsdN7Jd1hpjct&export=download [following]
# --2024-12-08 18:22:48--  https://drive.usercontent.google.com/download?id=16x6-8Znn2T50zFwVvKlzsdN7Jd1hpjct&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.2.132, 2607:f8b0:4023:c0d::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.2.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2515206 (2.4M) [application/octet-stream]
# Saving to: ‘Linear_regression_dataset’
#
# Linear_regression_d 100%[===================>]   2.40M  --.-KB/s    in 0.1s
#
# 2024-12-08 18:22:52 (17.3 MB/s) - ‘Linear_regression_dataset’ saved [2515206/2515206]

# %%
# Lets have a quick Look at dataset

print("(No of rows, No of Columns) = ",data_df.shape)
data_df.head()
# Out:
# (No of rows, No of Columns) =  (21613, 21)
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# So there are **19** features (of course we will not use id as feature :) ), and 1 variable to predict(price)
#
# But note that the **date** column contain strings so first we will remove T00.. part from it and than convert it to numpy array.

# %%
data_df['date'] = data_df['date'].str.replace('T000000','')            # Remove T000000 part from data column. Hint: search about .str.replace() method. :)
data_df = data_df.drop(columns=['id'])
data_array = np.array(data_df)                                         # Create a numpy array which does not have "id" field
assert (data_array.shape == (21613,20))
data_df.head()
# Out:
#        date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  20141013  221900.0         3       1.00         1180      5650     1.0
# 1  20141209  538000.0         3       2.25         2570      7242     2.0
# 2  20150225  180000.0         2       1.00          770     10000     1.0
# 3  20141209  604000.0         4       3.00         1960      5000     1.0
# 4  20150218  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503

# %% [markdown]
# Now the next task is **normalization**.
#
# We will scale each column of dataset by x -> (x-u)/s
#
# where u is mean(x), and s is standard deviation of u

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           21613 non-null  object
#  1   price          21613 non-null  float64
#  2   bedrooms       21613 non-null  int64
#  3   bathrooms      21613 non-null  float64
#  4   sqft_living    21613 non-null  int64
#  5   sqft_lot       21613 non-null  int64
#  6   floors         21613 non-null  float64
#  7   waterfront     21613 non-null  int64
#  8   view           21613 non-null  int64
#  9   condition      21613 non-null  int64
#  10  grade          21613 non-null  int64
#  11  sqft_above     21613 non-null  int64
#  12  sqft_basement  21613 non-null  int64
#  13  yr_built       21613 non-null  int64
#  14  yr_renovated   21613 non-null  int64
#  15  zipcode        21613 non-null  int64
#  16  lat            21613 non-null  float64
#  17  long           21613 non-null  float64
#  18  sqft_living15  21613 non-null  int64
#  19  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(14), object(1)
# memory usage: 3.3+ MB

# %%
data_df['date'] = data_df['date'].astype(int)

# %%
data_array = np.array(data_df)
mean = data_array.mean(axis=0)                             # this should be an array, each entry should be mean of a column
sd = data_array.std(axis=0)                                # this should be an array, each entry should be standard deviation of a column

data_array_norm = (data_array - mean)/sd

print(data_array_norm.shape)
# Out:
# (21613, 20)

# %% [markdown]
# The last step is to make train and test dataset and to create seperate vector for price

# %%
labels = data_df['price']                                                                                                            # extract the price column from data

x_array_norm = np.delete(data_array_norm, 1, axis=1)                                                                                                      # delete the price column from data_array_norm. Hint: use np.delete()

x_train, x_test, y_train, y_test = train_test_split(x_array_norm,labels,test_size=0.15,random_state=42,shuffle=True)    # splitting data into test and train set.

print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (18371, 19) (3242, 19) (18371,) (3242,)

# %% [markdown]
# ### **Loss and gradient descent**
# We will use mean squared error(MSE) as loss
#
# Use the gradient descent algorithm which you learned from tutorials
#
# Your task is to complete the following functions

# %%
def loss(y_pred,y_true):
  """
  input:
  y_pred = [array] predicted value of y
  y_true = [array] ground truth

  output:
  mse: [scalar] the MES loss
  """
  mse = (1/len(y_true)) * np.sum((y_true - y_pred) ** 2)                      # fill code here

  return mse

# %%
def y(x,a,b):
  """
  This function should return predicted value of y = ax+b
  input:
  x: [array] the feature vector of shape (m,n)
  a: [array] weights of shape (n,)
  b: [scalar] bias

  output:
  y_pred: [array] predicted value of y of shape (m,)
  """

  m,n = x.shape
  y_pred = np.dot(x,a) + b                   # fill code here

  assert(y_pred.shape == (m,))
  return y_pred

# %%
def gradient(x,a,b,y_true):
  """
  This function shoud return gradient of loss
  input:
  x: [array] the feature vector of shape (m,n)
  a: [array] weights of shape (n,)
  b: [scalar] bias
  y_true: [array] ground truth of shape (m,)

  output:
  grad: [tuple] a tuple (derivative with respect to a[array of shape(n,)], derivative with respect to b[scalar])
  """
  m,n = x.shape
  yp = y(x,a,b)

  da = (-2/m) * np.dot(x.T, (y_true - yp))             # write code to calculate derivative of loss with respect to a
  db = (-2/m) * np.sum(y_true - yp)              # write code to calculate derivative of loss with respect to b

  assert(da.shape ==(n,))
  return (da,db)

# %%
def gradient_descent(x,y_true,learning_rate=0.01,epochs = 10):
  """
  This function perfroms gradient descent and minimizes loss
  input:
  x: [array] the feature vector of shape (m,n)
  y_true: [array] ground truth of shape (m,)

  output:
  loss: [array] of size (epochs,)
  weights: [tuple] (a,b)
  """
  m,n = x.shape
  loss_mse = []                                 # initialize empty list to store loss
  a = np.zeros(n)                                       # initialize a- weights and b- bias
  b = 0

  for i in range(epochs):
    y_pred = y(x, a, b)
    # calculate derivative using gradient() function
    da, db = gradient(x, a, b, y_true)
    # apply gradient descent now to update a and b
    a = a - learning_rate * da
    b = b - learning_rate * db

    l_mse = loss(y_pred, y_true)                                # calculate loss at this point
    loss_mse.append(l_mse)

    print("Epoch ",i+1," Completed!","loss = ",l_mse)

  print("Training completed!!")

  assert(a.shape==(n,))

  return (loss_mse,a,b)

# %% [markdown]
# ### **Training**

# %%
epochs = 1000              # tweak this!!!
learn_rate = 0.01          # choose learning rate wisely otherwise loss may diverge!!

train_loss,a,b = gradient_descent(x_array_norm, labels, learning_rate=learn_rate, epochs=epochs)
# Out:
# Epoch  1  Completed! loss =  426471343102.3953
# Epoch  2  Completed! loss =  401795674066.3576
# Epoch  3  Completed! loss =  379842693782.7378
# Epoch  4  Completed! loss =  360170310045.58167
# Epoch  5  Completed! loss =  342419162312.56885
# Epoch  6  Completed! loss =  326296505246.20917
# Epoch  7  Completed! loss =  311563268243.68726
# Epoch  8  Completed! loss =  298023662745.61
# Epoch  9  Completed! loss =  285516833541.62885
# Epoch  10  Completed! loss =  273910150060.4479
# Epoch  11  Completed! loss =  263093813630.72903
# Epoch  12  Completed! loss =  252976520846.64462
# Epoch  13  Completed! loss =  243481974609.2099
# Epoch  14  Completed! loss =  234546075661.177
# Epoch  15  Completed! loss =  226114660508.9111
# Epoch  16  Completed! loss =  218141678148.6923
# Epoch  17  Completed! loss =  210587719285.66818
# Epoch  18  Completed! loss =  203418828792.24326
# Epoch  19  Completed! loss =  196605545833.7055
# Epoch  20  Completed! loss =  190122127061.59854
# Epoch  21  Completed! loss =  183945917076.328
# Epoch  22  Completed! loss =  178056837419.99686
# Epoch  23  Completed! loss =  172436971023.45624
# Epoch  24  Completed! loss =  167070223574.64487
# Epoch  25  Completed! loss =  161942046920.25986
# Epoch  26  Completed! loss =  157039212537.4926
# Epoch  27  Completed! loss =  152349625459.57776
# Epoch  28  Completed! loss =  147862170922.5848
# Epoch  29  Completed! loss =  143566587512.92743
# Epoch  30  Completed! loss =  139453361808.9978
# Epoch  31  Completed! loss =  135513640485.12315
# Epoch  32  Completed! loss =  131739156628.96611
# Epoch  33  Completed! loss =  128122167652.48152
# Epoch  34  Completed! loss =  124655402682.00432
# Epoch  35  Completed! loss =  121332017719.37604
# Epoch  36  Completed! loss =  118145557192.78123
# Epoch  37  Completed! loss =  115089920778.85759
# Epoch  38  Completed! loss =  112159334589.25082
# Epoch  39  Completed! loss =  109348325985.20827
# Epoch  40  Completed! loss =  106651701421.14656
# Epoch  41  Completed! loss =  104064526828.8917
# Epoch  42  Completed! loss =  101582110143.68683
# Epoch  43  Completed! loss =  99199985645.2899
# Epoch  44  Completed! loss =  96913899845.89204
# Epoch  45  Completed! loss =  94719798703.88454
# Epoch  46  Completed! loss =  92613815980.84825
# Epoch  47  Completed! loss =  90592262590.27892
# Epoch  48  Completed! loss =  88651616811.89082
# Epoch  49  Completed! loss =  86788515265.98334
# Epoch  50  Completed! loss =  84999744559.21457
# Epoch  51  Completed! loss =  83282233526.92688
# Epoch  52  Completed! loss =  81633046008.49829
# Epoch  53  Completed! loss =  80049374101.51878
# Epoch  54  Completed! loss =  78528531848.2909
# Epoch  55  Completed! loss =  77067949314.53612
# Epoch  56  Completed! loss =  75665167025.49533
# Epoch  57  Completed! loss =  74317830729.04485
# Epoch  58  Completed! loss =  73023686459.16728
# Epoch  59  Completed! loss =  71780575876.2483
# Epoch  60  Completed! loss =  70586431863.3227
# Epoch  61  Completed! loss =  69439274359.64978
# Epoch  62  Completed! loss =  68337206414.92669
# Epoch  63  Completed! loss =  67278410449.108894
# Epoch  64  Completed! loss =  66261144704.23942
# Epoch  65  Completed! loss =  65283739875.93618
# Epoch  66  Completed! loss =  64344595913.27402
# Epoch  67  Completed! loss =  63442178976.75544
# Epoch  68  Completed! loss =  62575018544.90699
# Epoch  69  Completed! loss =  61741704660.78796
# Epoch  70  Completed! loss =  60940885310.36458
# Epoch  71  Completed! loss =  60171263925.30143
# Epoch  72  Completed! loss =  59431597003.2582
# Epoch  73  Completed! loss =  58720691839.266045
# Epoch  74  Completed! loss =  58037404362.19681
# Epoch  75  Completed! loss =  57380637070.7387
# Epoch  76  Completed! loss =  56749337063.65685
# Epoch  77  Completed! loss =  56142494159.450554
# Epoch  78  Completed! loss =  55559139100.82657
# Epoch  79  Completed! loss =  54998341839.68842
# Epoch  80  Completed! loss =  54459209898.60251
# Epoch  81  Completed! loss =  53940886804.94177
# Epoch  82  Completed! loss =  53442550594.12988
# Epoch  83  Completed! loss =  52963412378.61575
# Epoch  84  Completed! loss =  52502714979.39939
# Epoch  85  Completed! loss =  52059731617.10849
# Epoch  86  Completed! loss =  51633764659.792145
# Epoch  87  Completed! loss =  51224144424.751884
# Epoch  88  Completed! loss =  50830228031.876656
# Epoch  89  Completed! loss =  50451398306.08253
# Epoch  90  Completed! loss =  50087062726.58594
# Epoch  91  Completed! loss =  49736652420.85741
# Epoch  92  Completed! loss =  49399621201.21485
# Epoch  93  Completed! loss =  49075444642.12005
# Epoch  94  Completed! loss =  48763619196.340454
# Epoch  95  Completed! loss =  48463661348.23112
# Epoch  96  Completed! loss =  48175106802.47873
# Epoch  97  Completed! loss =  47897509706.73181
# Epoch  98  Completed! loss =  47630441906.61863
# Epoch  99  Completed! loss =  47373492231.727356
# Epoch  100  Completed! loss =  47126265811.191986
# Epoch  101  Completed! loss =  46888383417.59249
# Epoch  102  Completed! loss =  46659480837.93957
# Epoch  103  Completed! loss =  46439208270.57185
# Epoch  104  Completed! loss =  46227229746.84947
# Epoch  105  Completed! loss =  46023222576.57908
# Epoch  106  Completed! loss =  45826876816.15511
# Epoch  107  Completed! loss =  45637894758.44951
# Epoch  108  Completed! loss =  45455990443.524956
# Epoch  109  Completed! loss =  45280889189.29066
# Epoch  110  Completed! loss =  45112327141.257965
# Epoch  111  Completed! loss =  44950050840.59223
# Epoch  112  Completed! loss =  44793816809.69261
# Epoch  113  Completed! loss =  44643391154.56608
# Epoch  114  Completed! loss =  44498549183.29452
# Epoch  115  Completed! loss =  44359075039.924385
# Epoch  116  Completed! loss =  44224761353.13827
# Epoch  117  Completed! loss =  44095408899.09549
# Epoch  118  Completed! loss =  43970826277.85564
# Epoch  119  Completed! loss =  43850829602.82435
# Epoch  120  Completed! loss =  43735242202.68489
# Epoch  121  Completed! loss =  43623894335.3022
# Epoch  122  Completed! loss =  43516622913.108025
# Epoch  123  Completed! loss =  43413271239.49692
# Epoch  124  Completed! loss =  43313688755.78256
# Epoch  125  Completed! loss =  43217730798.283516
# Epoch  126  Completed! loss =  43125258365.12523
# Epoch  127  Completed! loss =  43036137892.363
# Epoch  128  Completed! loss =  42950241039.046776
# Epoch  129  Completed! loss =  42867444480.865074
# Epoch  130  Completed! loss =  42787629712.02006
# Epoch  131  Completed! loss =  42710682855.000656
# Epoch  132  Completed! loss =  42636494477.93407
# Epoch  133  Completed! loss =  42564959419.20997
# Epoch  134  Completed! loss =  42495976619.08348
# Epoch  135  Completed! loss =  42429448957.97604
# Epoch  136  Completed! loss =  42365283101.204185
# Epoch  137  Completed! loss =  42303389349.87776
# Epoch  138  Completed! loss =  42243681497.71976
# Epoch  139  Completed! loss =  42186076693.56972
# Epoch  140  Completed! loss =  42130495309.34288
# Epoch  141  Completed! loss =  42076860813.22637
# Epoch  142  Completed! loss =  42025099647.902405
# Epoch  143  Completed! loss =  41975141113.59771
# Epoch  144  Completed! loss =  41926917255.76564
# Epoch  145  Completed! loss =  41880362757.216255
# Epoch  146  Completed! loss =  41835414834.51628
# Epoch  147  Completed! loss =  41792013138.48886
# Epoch  148  Completed! loss =  41750099658.64926
# Epoch  149  Completed! loss =  41709618631.41975
# Epoch  150  Completed! loss =  41670516451.97289
# Epoch  151  Completed! loss =  41632741589.55897
# Epoch  152  Completed! loss =  41596244506.17852
# Epoch  153  Completed! loss =  41560977578.467186
# Epoch  154  Completed! loss =  41526895022.66491
# Epoch  155  Completed! loss =  41493952822.546906
# Epoch  156  Completed! loss =  41462108660.19882
# Epoch  157  Completed! loss =  41431321849.52291
# Epoch  158  Completed! loss =  41401553272.36705
# Epoch  159  Completed! loss =  41372765317.17218
# Epoch  160  Completed! loss =  41344921820.03861
# Epoch  161  Completed! loss =  41317988008.11493
# Epoch  162  Completed! loss =  41291930445.21759
# Epoch  163  Completed! loss =  41266716979.592896
# Epoch  164  Completed! loss =  41242316693.73614
# Epoch  165  Completed! loss =  41218699856.18678
# Epoch  166  Completed! loss =  41195837875.22125
# Epoch  167  Completed! loss =  41173703254.3682
# Epoch  168  Completed! loss =  41152269549.67425
# Epoch  169  Completed! loss =  41131511328.650795
# Epoch  170  Completed! loss =  41111404130.835625
# Epoch  171  Completed! loss =  41091924429.9051
# Epoch  172  Completed! loss =  41073049597.276085
# Epoch  173  Completed! loss =  41054757867.13837
# Epoch  174  Completed! loss =  41037028302.86115
# Epoch  175  Completed! loss =  41019840764.719536
# Epoch  176  Completed! loss =  41003175878.88845
# Epoch  177  Completed! loss =  40987015007.654434
# Epoch  178  Completed! loss =  40971340220.79683
# Epoch  179  Completed! loss =  40956134268.092415
# Epoch  180  Completed! loss =  40941380552.89914
# Epoch  181  Completed! loss =  40927063106.776276
# Epoch  182  Completed! loss =  40913166565.10026
# Epoch  183  Completed! loss =  40899676143.63674
# Epoch  184  Completed! loss =  40886577616.03141
# Epoch  185  Completed! loss =  40873857292.18309
# Epoch  186  Completed! loss =  40861501997.46455
# Epoch  187  Completed! loss =  40849499052.7575
# Epoch  188  Completed! loss =  40837836255.2697
# Epoch  189  Completed! loss =  40826501860.10344
# Epoch  190  Completed! loss =  40815484562.54569
# Epoch  191  Completed! loss =  40804773481.05161
# Epoch  192  Completed! loss =  40794358140.89402
# Epoch  193  Completed! loss =  40784228458.452644
# Epoch  194  Completed! loss =  40774374726.118
# Epoch  195  Completed! loss =  40764787597.78563
# Epoch  196  Completed! loss =  40755458074.917595
# Epoch  197  Completed! loss =  40746377493.14874
# Epoch  198  Completed! loss =  40737537509.41643
# Epoch  199  Completed! loss =  40728930089.59309
# Epoch  200  Completed! loss =  40720547496.601906
# Epoch  201  Completed! loss =  40712382278.9965
# Epoch  202  Completed! loss =  40704427259.986404
# Epoch  203  Completed! loss =  40696675526.89098
# Epoch  204  Completed! loss =  40689120421.0047
# Epoch  205  Completed! loss =  40681755527.857765
# Epoch  206  Completed! loss =  40674574667.856445
# Epoch  207  Completed! loss =  40667571887.288414
# Epoch  208  Completed! loss =  40660741449.67847
# Epoch  209  Completed! loss =  40654077827.48105
# Epoch  210  Completed! loss =  40647575694.09638
# Epoch  211  Completed! loss =  40641229916.19735
# Epoch  212  Completed! loss =  40635035546.35509
# Epoch  213  Completed! loss =  40628987815.95143
# Epoch  214  Completed! loss =  40623082128.36716
# Epoch  215  Completed! loss =  40617314052.43489
# Epoch  216  Completed! loss =  40611679316.146675
# Epoch  217  Completed! loss =  40606173800.60587
# Epoch  218  Completed! loss =  40600793534.21411
# Epoch  219  Completed! loss =  40595534687.08374
# Epoch  220  Completed! loss =  40590393565.66736
# Epoch  221  Completed! loss =  40585366607.59554
# Epoch  222  Completed! loss =  40580450376.71477
# Epoch  223  Completed! loss =  40575641558.31782
# Epoch  224  Completed! loss =  40570936954.55881
# Epoch  225  Completed! loss =  40566333480.04599
# Epoch  226  Completed! loss =  40561828157.60503
# Epoch  227  Completed! loss =  40557418114.20635
# Epoch  228  Completed! loss =  40553100577.049965
# Epoch  229  Completed! loss =  40548872869.80165
# Epoch  230  Completed! loss =  40544732408.97465
# Epoch  231  Completed! loss =  40540676700.45108
# Epoch  232  Completed! loss =  40536703336.13767
# Epoch  233  Completed! loss =  40532809990.750595
# Epoch  234  Completed! loss =  40528994418.724174
# Epoch  235  Completed! loss =  40525254451.238945
# Epoch  236  Completed! loss =  40521587993.36406
# Epoch  237  Completed! loss =  40517993021.30986
# Epoch  238  Completed! loss =  40514467579.78608
# Epoch  239  Completed! loss =  40511009779.461754
# Epoch  240  Completed! loss =  40507617794.52278
# Epoch  241  Completed! loss =  40504289860.32322
# Epoch  242  Completed! loss =  40501024271.126884
# Epoch  243  Completed! loss =  40497819377.9356
# Epoch  244  Completed! loss =  40494673586.40065
# Epoch  245  Completed! loss =  40491585354.814384
# Epoch  246  Completed! loss =  40488553192.17867
# Epoch  247  Completed! loss =  40485575656.34732
# Epoch  248  Completed! loss =  40482651352.23955
# Epoch  249  Completed! loss =  40479778930.12169
# Epoch  250  Completed! loss =  40476957083.95465
# Epoch  251  Completed! loss =  40474184549.80428
# Epoch  252  Completed! loss =  40471460104.31254
# Epoch  253  Completed! loss =  40468782563.22673
# Epoch  254  Completed! loss =  40466150779.98496
# Epoch  255  Completed! loss =  40463563644.35528
# Epoch  256  Completed! loss =  40461020081.12656
# Epoch  257  Completed! loss =  40458519048.84916
# Epoch  258  Completed! loss =  40456059538.62341
# Epoch  259  Completed! loss =  40453640572.933975
# Epoch  260  Completed! loss =  40451261204.52837
# Epoch  261  Completed! loss =  40448920515.33805
# Epoch  262  Completed! loss =  40446617615.44014
# Epoch  263  Completed! loss =  40444351642.05852
# Epoch  264  Completed! loss =  40442121758.6026
# Epoch  265  Completed! loss =  40439927153.74226
# Epoch  266  Completed! loss =  40437767040.517746
# Epoch  267  Completed! loss =  40435640655.483
# Epoch  268  Completed! loss =  40433547257.881195
# Epoch  269  Completed! loss =  40431486128.85131
# Epoch  270  Completed! loss =  40429456570.66432
# Epoch  271  Completed! loss =  40427457905.988174
# Epoch  272  Completed! loss =  40425489477.180176
# Epoch  273  Completed! loss =  40423550645.60583
# Epoch  274  Completed! loss =  40421640790.98315
# Epoch  275  Completed! loss =  40419759310.75142
# Epoch  276  Completed! loss =  40417905619.46348
# Epoch  277  Completed! loss =  40416079148.20051
# Epoch  278  Completed! loss =  40414279344.00873
# Epoch  279  Completed! loss =  40412505669.35687
# Epoch  280  Completed! loss =  40410757601.6138
# Epoch  281  Completed! loss =  40409034632.54542
# Epoch  282  Completed! loss =  40407336267.83025
# Epoch  283  Completed! loss =  40405662026.59281
# Epoch  284  Completed! loss =  40404011440.95419
# Epoch  285  Completed! loss =  40402384055.59918
# Epoch  286  Completed! loss =  40400779427.35929
# Epoch  287  Completed! loss =  40399197124.811104
# Epoch  288  Completed! loss =  40397636727.88921
# Epoch  289  Completed! loss =  40396097827.51343
# Epoch  290  Completed! loss =  40394580025.22955
# Epoch  291  Completed! loss =  40393082932.8632
# Epoch  292  Completed! loss =  40391606172.18625
# Epoch  293  Completed! loss =  40390149374.59541
# Epoch  294  Completed! loss =  40388712180.80237
# Epoch  295  Completed! loss =  40387294240.53523
# Epoch  296  Completed! loss =  40385895212.25065
# Epoch  297  Completed! loss =  40384514762.85645
# Epoch  298  Completed! loss =  40383152567.44405
# Epoch  299  Completed! loss =  40381808309.030655
# Epoch  300  Completed! loss =  40380481678.31058
# Epoch  301  Completed! loss =  40379172373.41549
# Epoch  302  Completed! loss =  40377880099.683205
# Epoch  303  Completed! loss =  40376604569.43469
# Epoch  304  Completed! loss =  40375345501.75902
# Epoch  305  Completed! loss =  40374102622.30591
# Epoch  306  Completed! loss =  40372875663.085556
# Epoch  307  Completed! loss =  40371664362.275696
# Epoch  308  Completed! loss =  40370468464.03518
# Epoch  309  Completed! loss =  40369287718.32434
# Epoch  310  Completed! loss =  40368121880.73152
# Epoch  311  Completed! loss =  40366970712.30564
# Epoch  312  Completed! loss =  40365833979.394714
# Epoch  313  Completed! loss =  40364711453.489815
# Epoch  314  Completed! loss =  40363602911.07458
# Epoch  315  Completed! loss =  40362508133.47981
# Epoch  316  Completed! loss =  40361426906.743195
# Epoch  317  Completed! loss =  40360359021.4737
# Epoch  318  Completed! loss =  40359304272.72074
# Epoch  319  Completed! loss =  40358262459.847786
# Epoch  320  Completed! loss =  40357233386.41016
# Epoch  321  Completed! loss =  40356216860.03714
# Epoch  322  Completed! loss =  40355212692.318
# Epoch  323  Completed! loss =  40354220698.69179
# Epoch  324  Completed! loss =  40353240698.341
# Epoch  325  Completed! loss =  40352272514.08865
# Epoch  326  Completed! loss =  40351315972.298836
# Epoch  327  Completed! loss =  40350370902.78066
# Epoch  328  Completed! loss =  40349437138.69526
# Epoch  329  Completed! loss =  40348514516.465996
# Epoch  330  Completed! loss =  40347602875.69146
# Epoch  331  Completed! loss =  40346702059.06153
# Epoch  332  Completed! loss =  40345811912.276024
# Epoch  333  Completed! loss =  40344932283.965996
# Epoch  334  Completed! loss =  40344063025.61771
# Epoch  335  Completed! loss =  40343203991.49896
# Epoch  336  Completed! loss =  40342355038.58782
# Epoch  337  Completed! loss =  40341516026.50361
# Epoch  338  Completed! loss =  40340686817.44016
# Epoch  339  Completed! loss =  40339867276.10118
# Epoch  340  Completed! loss =  40339057269.63751
# Epoch  341  Completed! loss =  40338256667.586685
# Epoch  342  Completed! loss =  40337465341.81402
# Epoch  343  Completed! loss =  40336683166.4558
# Epoch  344  Completed! loss =  40335910017.86421
# Epoch  345  Completed! loss =  40335145774.55378
# Epoch  346  Completed! loss =  40334390317.14972
# Epoch  347  Completed! loss =  40333643528.33772
# Epoch  348  Completed! loss =  40332905292.81529
# Epoch  349  Completed! loss =  40332175497.24461
# Epoch  350  Completed! loss =  40331454030.206764
# Epoch  351  Completed! loss =  40330740782.15743
# Epoch  352  Completed! loss =  40330035645.3838
# Epoch  353  Completed! loss =  40329338513.962875
# Epoch  354  Completed! loss =  40328649283.7209
# Epoch  355  Completed! loss =  40327967852.194145
# Epoch  356  Completed! loss =  40327294118.590645
# Epoch  357  Completed! loss =  40326627983.753265
# Epoch  358  Completed! loss =  40325969350.123634
# Epoch  359  Completed! loss =  40325318121.7073
# Epoch  360  Completed! loss =  40324674204.03975
# Epoch  361  Completed! loss =  40324037504.15352
# Epoch  362  Completed! loss =  40323407930.546135
# Epoch  363  Completed! loss =  40322785393.14903
# Epoch  364  Completed! loss =  40322169803.29732
# Epoch  365  Completed! loss =  40321561073.70037
# Epoch  366  Completed! loss =  40320959118.4133
# Epoch  367  Completed! loss =  40320363852.809135
# Epoch  368  Completed! loss =  40319775193.55186
# Epoch  369  Completed! loss =  40319193058.570076
# Epoch  370  Completed! loss =  40318617367.031494
# Epoch  371  Completed! loss =  40318048039.31801
# Epoch  372  Completed! loss =  40317484997.00157
# Epoch  373  Completed! loss =  40316928162.820526
# Epoch  374  Completed! loss =  40316377460.656784
# Epoch  375  Completed! loss =  40315832815.5134
# Epoch  376  Completed! loss =  40315294153.49293
# Epoch  377  Completed! loss =  40314761401.776146
# Epoch  378  Completed! loss =  40314234488.60148
# Epoch  379  Completed! loss =  40313713343.24489
# Epoch  380  Completed! loss =  40313197896.000305
# Epoch  381  Completed! loss =  40312688078.16048
# Epoch  382  Completed! loss =  40312183821.99845
# Epoch  383  Completed! loss =  40311685060.74935
# Epoch  384  Completed! loss =  40311191728.592735
# Epoch  385  Completed! loss =  40310703760.635345
# Epoch  386  Completed! loss =  40310221092.89423
# Epoch  387  Completed! loss =  40309743662.28039
# Epoch  388  Completed! loss =  40309271406.582695
# Epoch  389  Completed! loss =  40308804264.452324
# Epoch  390  Completed! loss =  40308342175.38742
# Epoch  391  Completed! loss =  40307885079.71828
# Epoch  392  Completed! loss =  40307432918.59274
# Epoch  393  Completed! loss =  40306985633.962006
# Epoch  394  Completed! loss =  40306543168.566765
# Epoch  395  Completed! loss =  40306105465.92367
# Epoch  396  Completed! loss =  40305672470.31203
# Epoch  397  Completed! loss =  40305244126.76095
# Epoch  398  Completed! loss =  40304820381.03663
# Epoch  399  Completed! loss =  40304401179.63003
# Epoch  400  Completed! loss =  40303986469.74477
# Epoch  401  Completed! loss =  40303576199.28535
# Epoch  402  Completed! loss =  40303170316.84556
# Epoch  403  Completed! loss =  40302768771.69719
# Epoch  404  Completed! loss =  40302371513.779
# Epoch  405  Completed! loss =  40301978493.68586
# Epoch  406  Completed! loss =  40301589662.6582
# Epoch  407  Completed! loss =  40301204972.571655
# Epoch  408  Completed! loss =  40300824375.92691
# Epoch  409  Completed! loss =  40300447825.83977
# Epoch  410  Completed! loss =  40300075276.03149
# Epoch  411  Completed! loss =  40299706680.819214
# Epoch  412  Completed! loss =  40299341995.10667
# Epoch  413  Completed! loss =  40298981174.375046
# Epoch  414  Completed! loss =  40298624174.67407
# Epoch  415  Completed! loss =  40298270952.61321
# Epoch  416  Completed! loss =  40297921465.35312
# Epoch  417  Completed! loss =  40297575670.59722
# Epoch  418  Completed! loss =  40297233526.58347
# Epoch  419  Completed! loss =  40296894992.07623
# Epoch  420  Completed! loss =  40296560026.35841
# Epoch  421  Completed! loss =  40296228589.22366
# Epoch  422  Completed! loss =  40295900640.96875
# Epoch  423  Completed! loss =  40295576142.38609
# Epoch  424  Completed! loss =  40295255054.756454
# Epoch  425  Completed! loss =  40294937339.84172
# Epoch  426  Completed! loss =  40294622959.877846
# Epoch  427  Completed! loss =  40294311877.567955
# Epoch  428  Completed! loss =  40294004056.07552
# Epoch  429  Completed! loss =  40293699459.01772
# Epoch  430  Completed! loss =  40293398050.458885
# Epoch  431  Completed! loss =  40293099794.904045
# Epoch  432  Completed! loss =  40292804657.29267
# Epoch  433  Completed! loss =  40292512602.99244
# Epoch  434  Completed! loss =  40292223597.79315
# Epoch  435  Completed! loss =  40291937607.900795
# Epoch  436  Completed! loss =  40291654599.93164
# Epoch  437  Completed! loss =  40291374540.90648
# Epoch  438  Completed! loss =  40291097398.24498
# Epoch  439  Completed! loss =  40290823139.7601
# Epoch  440  Completed! loss =  40290551733.65264
# Epoch  441  Completed! loss =  40290283148.505844
# Epoch  442  Completed! loss =  40290017353.28014
# Epoch  443  Completed! loss =  40289754317.307976
# Epoch  444  Completed! loss =  40289494010.28863
# Epoch  445  Completed! loss =  40289236402.28327
# Epoch  446  Completed! loss =  40288981463.71001
# Epoch  447  Completed! loss =  40288729165.33904
# Epoch  448  Completed! loss =  40288479478.28787
# Epoch  449  Completed! loss =  40288232374.016624
# Epoch  450  Completed! loss =  40287987824.323456
# Epoch  451  Completed! loss =  40287745801.33998
# Epoch  452  Completed! loss =  40287506277.526855
# Epoch  453  Completed! loss =  40287269225.66932
# Epoch  454  Completed! loss =  40287034618.87293
# Epoch  455  Completed! loss =  40286802430.55932
# Epoch  456  Completed! loss =  40286572634.461945
# Epoch  457  Completed! loss =  40286345204.62206
# Epoch  458  Completed! loss =  40286120115.38459
# Epoch  459  Completed! loss =  40285897341.39419
# Epoch  460  Completed! loss =  40285676857.59129
# Epoch  461  Completed! loss =  40285458639.20828
# Epoch  462  Completed! loss =  40285242661.76563
# Epoch  463  Completed! loss =  40285028901.06823
# Epoch  464  Completed! loss =  40284817333.20166
# Epoch  465  Completed! loss =  40284607934.52853
# Epoch  466  Completed! loss =  40284400681.684975
# Epoch  467  Completed! loss =  40284195551.577095
# Epoch  468  Completed! loss =  40283992521.37749
# Epoch  469  Completed! loss =  40283791568.521835
# Epoch  470  Completed! loss =  40283592670.70558
# Epoch  471  Completed! loss =  40283395805.88055
# Epoch  472  Completed! loss =  40283200952.251724
# Epoch  473  Completed! loss =  40283008088.27403
# Epoch  474  Completed! loss =  40282817192.64919
# Epoch  475  Completed! loss =  40282628244.32255
# Epoch  476  Completed! loss =  40282441222.48004
# Epoch  477  Completed! loss =  40282256106.545135
# Epoch  478  Completed! loss =  40282072876.175896
# Epoch  479  Completed! loss =  40281891511.26198
# Epoch  480  Completed! loss =  40281711991.92181
# Epoch  481  Completed! loss =  40281534298.499626
# Epoch  482  Completed! loss =  40281358411.56275
# Epoch  483  Completed! loss =  40281184311.89879
# Epoch  484  Completed! loss =  40281011980.51286
# Epoch  485  Completed! loss =  40280841398.62496
# Epoch  486  Completed! loss =  40280672547.66725
# Epoch  487  Completed! loss =  40280505409.28147
# Epoch  488  Completed! loss =  40280339965.31634
# Epoch  489  Completed! loss =  40280176197.82498
# Epoch  490  Completed! loss =  40280014089.0625
# Epoch  491  Completed! loss =  40279853621.48339
# Epoch  492  Completed! loss =  40279694777.73921
# Epoch  493  Completed! loss =  40279537540.676056
# Epoch  494  Completed! loss =  40279381893.33228
# Epoch  495  Completed! loss =  40279227818.9361
# Epoch  496  Completed! loss =  40279075300.903305
# Epoch  497  Completed! loss =  40278924322.835
# Epoch  498  Completed! loss =  40278774868.51532
# Epoch  499  Completed! loss =  40278626921.9092
# Epoch  500  Completed! loss =  40278480467.16028
# Epoch  501  Completed! loss =  40278335488.58863
# Epoch  502  Completed! loss =  40278191970.688736
# Epoch  503  Completed! loss =  40278049898.12732
# Epoch  504  Completed! loss =  40277909255.74128
# Epoch  505  Completed! loss =  40277770028.53569
# Epoch  506  Completed! loss =  40277632201.68178
# Epoch  507  Completed! loss =  40277495760.51488
# Epoch  508  Completed! loss =  40277360690.532555
# Epoch  509  Completed! loss =  40277226977.39262
# Epoch  510  Completed! loss =  40277094606.911194
# Epoch  511  Completed! loss =  40276963565.06091
# Epoch  512  Completed! loss =  40276833837.968994
# Epoch  513  Completed! loss =  40276705411.915405
# Epoch  514  Completed! loss =  40276578273.33112
# Epoch  515  Completed! loss =  40276452408.796234
# Epoch  516  Completed! loss =  40276327805.038284
# Epoch  517  Completed! loss =  40276204448.930466
# Epoch  518  Completed! loss =  40276082327.48994
# Epoch  519  Completed! loss =  40275961427.87611
# Epoch  520  Completed! loss =  40275841737.38896
# Epoch  521  Completed! loss =  40275723243.46745
# Epoch  522  Completed! loss =  40275605933.6878
# Epoch  523  Completed! loss =  40275489795.761955
# Epoch  524  Completed! loss =  40275374817.53595
# Epoch  525  Completed! loss =  40275260986.988365
# Epoch  526  Completed! loss =  40275148292.22881
# Epoch  527  Completed! loss =  40275036721.49631
# Epoch  528  Completed! loss =  40274926263.15789
# Epoch  529  Completed! loss =  40274816905.707016
# Epoch  530  Completed! loss =  40274708637.762184
# Epoch  531  Completed! loss =  40274601448.065414
# Epoch  532  Completed! loss =  40274495325.48088
# Epoch  533  Completed! loss =  40274390258.99344
# Epoch  534  Completed! loss =  40274286237.707245
# Epoch  535  Completed! loss =  40274183250.84439
# Epoch  536  Completed! loss =  40274081287.74357
# Epoch  537  Completed! loss =  40273980337.85865
# Epoch  538  Completed! loss =  40273880390.75743
# Epoch  539  Completed! loss =  40273781436.12029
# Epoch  540  Completed! loss =  40273683463.738884
# Epoch  541  Completed! loss =  40273586463.514915
# Epoch  542  Completed! loss =  40273490425.45881
# Epoch  543  Completed! loss =  40273395339.68853
# Epoch  544  Completed! loss =  40273301196.428276
# Epoch  545  Completed! loss =  40273207986.00735
# Epoch  546  Completed! loss =  40273115698.858894
# Epoch  547  Completed! loss =  40273024325.51873
# Epoch  548  Completed! loss =  40272933856.62418
# Epoch  549  Completed! loss =  40272844282.91295
# Epoch  550  Completed! loss =  40272755595.22188
# Epoch  551  Completed! loss =  40272667784.48596
# Epoch  552  Completed! loss =  40272580841.73712
# Epoch  553  Completed! loss =  40272494758.10316
# Epoch  554  Completed! loss =  40272409524.80663
# Epoch  555  Completed! loss =  40272325133.16385
# Epoch  556  Completed! loss =  40272241574.5837
# Epoch  557  Completed! loss =  40272158840.56674
# Epoch  558  Completed! loss =  40272076922.70403
# Epoch  559  Completed! loss =  40271995812.67623
# Epoch  560  Completed! loss =  40271915502.252464
# Epoch  561  Completed! loss =  40271835983.289444
# Epoch  562  Completed! loss =  40271757247.73041
# Epoch  563  Completed! loss =  40271679287.60419
# Epoch  564  Completed! loss =  40271602095.024216
# Epoch  565  Completed! loss =  40271525662.18758
# Epoch  566  Completed! loss =  40271449981.37412
# Epoch  567  Completed! loss =  40271375044.94547
# Epoch  568  Completed! loss =  40271300845.34414
# Epoch  569  Completed! loss =  40271227375.092606
# Epoch  570  Completed! loss =  40271154626.79247
# Epoch  571  Completed! loss =  40271082593.12351
# Epoch  572  Completed! loss =  40271011266.84284
# Epoch  573  Completed! loss =  40270940640.78402
# Epoch  574  Completed! loss =  40270870707.85628
# Epoch  575  Completed! loss =  40270801461.04356
# Epoch  576  Completed! loss =  40270732893.403786
# Epoch  577  Completed! loss =  40270664998.06801
# Epoch  578  Completed! loss =  40270597768.239555
# Epoch  579  Completed! loss =  40270531197.19328
# Epoch  580  Completed! loss =  40270465278.274765
# Epoch  581  Completed! loss =  40270400004.899506
# Epoch  582  Completed! loss =  40270335370.55215
# Epoch  583  Completed! loss =  40270271368.78576
# Epoch  584  Completed! loss =  40270207993.221
# Epoch  585  Completed! loss =  40270145237.54547
# Epoch  586  Completed! loss =  40270083095.5129
# Epoch  587  Completed! loss =  40270021560.94244
# Epoch  588  Completed! loss =  40269960627.71792
# Epoch  589  Completed! loss =  40269900289.7872
# Epoch  590  Completed! loss =  40269840541.161415
# Epoch  591  Completed! loss =  40269781375.914276
# Epoch  592  Completed! loss =  40269722788.18141
# Epoch  593  Completed! loss =  40269664772.15965
# Epoch  594  Completed! loss =  40269607322.10641
# Epoch  595  Completed! loss =  40269550432.33897
# Epoch  596  Completed! loss =  40269494097.233826
# Epoch  597  Completed! loss =  40269438311.226105
# Epoch  598  Completed! loss =  40269383068.80884
# Epoch  599  Completed! loss =  40269328364.53239
# Epoch  600  Completed! loss =  40269274193.003784
# Epoch  601  Completed! loss =  40269220548.88614
# Epoch  602  Completed! loss =  40269167426.897995
# Epoch  603  Completed! loss =  40269114821.812775
# Epoch  604  Completed! loss =  40269062728.458145
# Epoch  605  Completed! loss =  40269011141.71543
# Epoch  606  Completed! loss =  40268960056.519
# Epoch  607  Completed! loss =  40268909467.8558
# Epoch  608  Completed! loss =  40268859370.76463
# Epoch  609  Completed! loss =  40268809760.335724
# Epoch  610  Completed! loss =  40268760631.7101
# Epoch  611  Completed! loss =  40268711980.079
# Epoch  612  Completed! loss =  40268663800.68345
# Epoch  613  Completed! loss =  40268616088.8136
# Epoch  614  Completed! loss =  40268568839.80828
# Epoch  615  Completed! loss =  40268522049.05441
# Epoch  616  Completed! loss =  40268475711.98654
# Epoch  617  Completed! loss =  40268429824.08628
# Epoch  618  Completed! loss =  40268384380.88186
# Epoch  619  Completed! loss =  40268339377.94753
# Epoch  620  Completed! loss =  40268294810.90318
# Epoch  621  Completed! loss =  40268250675.41373
# Epoch  622  Completed! loss =  40268206967.18874
# Epoch  623  Completed! loss =  40268163681.9819
# Epoch  624  Completed! loss =  40268120815.590515
# Epoch  625  Completed! loss =  40268078363.85513
# Epoch  626  Completed! loss =  40268036322.65894
# Epoch  627  Completed! loss =  40267994687.927475
# Epoch  628  Completed! loss =  40267953455.62799
# Epoch  629  Completed! loss =  40267912621.76915
# Epoch  630  Completed! loss =  40267872182.40053
# Epoch  631  Completed! loss =  40267832133.61219
# Epoch  632  Completed! loss =  40267792471.534225
# Epoch  633  Completed! loss =  40267753192.33633
# Epoch  634  Completed! loss =  40267714292.22743
# Epoch  635  Completed! loss =  40267675767.4552
# Epoch  636  Completed! loss =  40267637614.30571
# Epoch  637  Completed! loss =  40267599829.102936
# Epoch  638  Completed! loss =  40267562408.20843
# Epoch  639  Completed! loss =  40267525348.02092
# Epoch  640  Completed! loss =  40267488644.97584
# Epoch  641  Completed! loss =  40267452295.545
# Epoch  642  Completed! loss =  40267416296.23621
# Epoch  643  Completed! loss =  40267380643.59287
# Epoch  644  Completed! loss =  40267345334.19357
# Epoch  645  Completed! loss =  40267310364.651764
# Epoch  646  Completed! loss =  40267275731.61537
# Epoch  647  Completed! loss =  40267241431.76644
# Epoch  648  Completed! loss =  40267207461.820724
# Epoch  649  Completed! loss =  40267173818.52741
# Epoch  650  Completed! loss =  40267140498.6687
# Epoch  651  Completed! loss =  40267107499.05948
# Epoch  652  Completed! loss =  40267074816.547
# Epoch  653  Completed! loss =  40267042448.01046
# Epoch  654  Completed! loss =  40267010390.36078
# Epoch  655  Completed! loss =  40266978640.540184
# Epoch  656  Completed! loss =  40266947195.52189
# Epoch  657  Completed! loss =  40266916052.309784
# Epoch  658  Completed! loss =  40266885207.93811
# Epoch  659  Completed! loss =  40266854659.47113
# Epoch  660  Completed! loss =  40266824404.00283
# Epoch  661  Completed! loss =  40266794438.65659
# Epoch  662  Completed! loss =  40266764760.584885
# Epoch  663  Completed! loss =  40266735366.96897
# Epoch  664  Completed! loss =  40266706255.01858
# Epoch  665  Completed! loss =  40266677421.97163
# Epoch  666  Completed! loss =  40266648865.09395
# Epoch  667  Completed! loss =  40266620581.67894
# Epoch  668  Completed! loss =  40266592569.04731
# Epoch  669  Completed! loss =  40266564824.54681
# Epoch  670  Completed! loss =  40266537345.551895
# Epoch  671  Completed! loss =  40266510129.463524
# Epoch  672  Completed! loss =  40266483173.708786
# Epoch  673  Completed! loss =  40266456475.7407
# Epoch  674  Completed! loss =  40266430033.037964
# Epoch  675  Completed! loss =  40266403843.10456
# Epoch  676  Completed! loss =  40266377903.46966
# Epoch  677  Completed! loss =  40266352211.68721
# Epoch  678  Completed! loss =  40266326765.33579
# Epoch  679  Completed! loss =  40266301562.01831
# Epoch  680  Completed! loss =  40266276599.361694
# Epoch  681  Completed! loss =  40266251875.01676
# Epoch  682  Completed! loss =  40266227386.657875
# Epoch  683  Completed! loss =  40266203131.98272
# Epoch  684  Completed! loss =  40266179108.7121
# Epoch  685  Completed! loss =  40266155314.58962
# Epoch  686  Completed! loss =  40266131747.381546
# Epoch  687  Completed! loss =  40266108404.8765
# Epoch  688  Completed! loss =  40266085284.885254
# Epoch  689  Completed! loss =  40266062385.24049
# Epoch  690  Completed! loss =  40266039703.79657
# Epoch  691  Completed! loss =  40266017238.42932
# Epoch  692  Completed! loss =  40265994987.035835
# Epoch  693  Completed! loss =  40265972947.53421
# Epoch  694  Completed! loss =  40265951117.86333
# Epoch  695  Completed! loss =  40265929495.98268
# Epoch  696  Completed! loss =  40265908079.872154
# Epoch  697  Completed! loss =  40265886867.53178
# Epoch  698  Completed! loss =  40265865856.981514
# Epoch  699  Completed! loss =  40265845046.261116
# Epoch  700  Completed! loss =  40265824433.42987
# Epoch  701  Completed! loss =  40265804016.56642
# Epoch  702  Completed! loss =  40265783793.76853
# Epoch  703  Completed! loss =  40265763763.15295
# Epoch  704  Completed! loss =  40265743922.85513
# Epoch  705  Completed! loss =  40265724271.02915
# Epoch  706  Completed! loss =  40265704805.8474
# Epoch  707  Completed! loss =  40265685525.500496
# Epoch  708  Completed! loss =  40265666428.197014
# Epoch  709  Completed! loss =  40265647512.16337
# Epoch  710  Completed! loss =  40265628775.64358
# Epoch  711  Completed! loss =  40265610216.89912
# Epoch  712  Completed! loss =  40265591834.20873
# Epoch  713  Completed! loss =  40265573625.86825
# Epoch  714  Completed! loss =  40265555590.19042
# Epoch  715  Completed! loss =  40265537725.50472
# Epoch  716  Completed! loss =  40265520030.15723
# Epoch  717  Completed! loss =  40265502502.510376
# Epoch  718  Completed! loss =  40265485140.942856
# Epoch  719  Completed! loss =  40265467943.84944
# Epoch  720  Completed! loss =  40265450909.640785
# Epoch  721  Completed! loss =  40265434036.74327
# Epoch  722  Completed! loss =  40265417323.59889
# Epoch  723  Completed! loss =  40265400768.66503
# Epoch  724  Completed! loss =  40265384370.414345
# Epoch  725  Completed! loss =  40265368127.33462
# Epoch  726  Completed! loss =  40265352037.928535
# Epoch  727  Completed! loss =  40265336100.713646
# Epoch  728  Completed! loss =  40265320314.2221
# Epoch  729  Completed! loss =  40265304677.00057
# Epoch  730  Completed! loss =  40265289187.61006
# Epoch  731  Completed! loss =  40265273844.62582
# Epoch  732  Completed! loss =  40265258646.63712
# Epoch  733  Completed! loss =  40265243592.24717
# Epoch  734  Completed! loss =  40265228680.072945
# Epoch  735  Completed! loss =  40265213908.74507
# Epoch  736  Completed! loss =  40265199276.90768
# Epoch  737  Completed! loss =  40265184783.218216
# Epoch  738  Completed! loss =  40265170426.34741
# Epoch  739  Completed! loss =  40265156204.97908
# Epoch  740  Completed! loss =  40265142117.80994
# Epoch  741  Completed! loss =  40265128163.5496
# Epoch  742  Completed! loss =  40265114340.920334
# Epoch  743  Completed! loss =  40265100648.657005
# Epoch  744  Completed! loss =  40265087085.50688
# Epoch  745  Completed! loss =  40265073650.2296
# Epoch  746  Completed! loss =  40265060341.59695
# Epoch  747  Completed! loss =  40265047158.3928
# Epoch  748  Completed! loss =  40265034099.41296
# Epoch  749  Completed! loss =  40265021163.46506
# Epoch  750  Completed! loss =  40265008349.36846
# Epoch  751  Completed! loss =  40264995655.9541
# Epoch  752  Completed! loss =  40264983082.06436
# Epoch  753  Completed! loss =  40264970626.55302
# Epoch  754  Completed! loss =  40264958288.28506
# Epoch  755  Completed! loss =  40264946066.1366
# Epoch  756  Completed! loss =  40264933958.9948
# Epoch  757  Completed! loss =  40264921965.75768
# Epoch  758  Completed! loss =  40264910085.3341
# Epoch  759  Completed! loss =  40264898316.64356
# Epoch  760  Completed! loss =  40264886658.61618
# Epoch  761  Completed! loss =  40264875110.19253
# Epoch  762  Completed! loss =  40264863670.32351
# Epoch  763  Completed! loss =  40264852337.97036
# Epoch  764  Completed! loss =  40264841112.104416
# Epoch  765  Completed! loss =  40264829991.7071
# Epoch  766  Completed! loss =  40264818975.769775
# Epoch  767  Completed! loss =  40264808063.29366
# Epoch  768  Completed! loss =  40264797253.28975
# Epoch  769  Completed! loss =  40264786544.77868
# Epoch  770  Completed! loss =  40264775936.79064
# Epoch  771  Completed! loss =  40264765428.3653
# Epoch  772  Completed! loss =  40264755018.551704
# Epoch  773  Completed! loss =  40264744706.40816
# Epoch  774  Completed! loss =  40264734491.002174
# Epoch  775  Completed! loss =  40264724371.41033
# Epoch  776  Completed! loss =  40264714346.71823
# Epoch  777  Completed! loss =  40264704416.02037
# Epoch  778  Completed! loss =  40264694578.42007
# Epoch  779  Completed! loss =  40264684833.0294
# Epoch  780  Completed! loss =  40264675178.96907
# Epoch  781  Completed! loss =  40264665615.36834
# Epoch  782  Completed! loss =  40264656141.36495
# Epoch  783  Completed! loss =  40264646756.105034
# Epoch  784  Completed! loss =  40264637458.74302
# Epoch  785  Completed! loss =  40264628248.441574
# Epoch  786  Completed! loss =  40264619124.37151
# Epoch  787  Completed! loss =  40264610085.71168
# Epoch  788  Completed! loss =  40264601131.64892
# Epoch  789  Completed! loss =  40264592261.37798
# Epoch  790  Completed! loss =  40264583474.10143
# Epoch  791  Completed! loss =  40264574769.02956
# Epoch  792  Completed! loss =  40264566145.380356
# Epoch  793  Completed! loss =  40264557602.37939
# Epoch  794  Completed! loss =  40264549139.25973
# Epoch  795  Completed! loss =  40264540755.26188
# Epoch  796  Completed! loss =  40264532449.63376
# Epoch  797  Completed! loss =  40264524221.63052
# Epoch  798  Completed! loss =  40264516070.51458
# Epoch  799  Completed! loss =  40264507995.55548
# Epoch  800  Completed! loss =  40264499996.02983
# Epoch  801  Completed! loss =  40264492071.221275
# Epoch  802  Completed! loss =  40264484220.42039
# Epoch  803  Completed! loss =  40264476442.92461
# Epoch  804  Completed! loss =  40264468738.038155
# Epoch  805  Completed! loss =  40264461105.07202
# Epoch  806  Completed! loss =  40264453543.34385
# Epoch  807  Completed! loss =  40264446052.17787
# Epoch  808  Completed! loss =  40264438630.90486
# Epoch  809  Completed! loss =  40264431278.86208
# Epoch  810  Completed! loss =  40264423995.39316
# Epoch  811  Completed! loss =  40264416779.848114
# Epoch  812  Completed! loss =  40264409631.583206
# Epoch  813  Completed! loss =  40264402549.96093
# Epoch  814  Completed! loss =  40264395534.34995
# Epoch  815  Completed! loss =  40264388584.12501
# Epoch  816  Completed! loss =  40264381698.666885
# Epoch  817  Completed! loss =  40264374877.362335
# Epoch  818  Completed! loss =  40264368119.604034
# Epoch  819  Completed! loss =  40264361424.790535
# Epoch  820  Completed! loss =  40264354792.32613
# Epoch  821  Completed! loss =  40264348221.62095
# Epoch  822  Completed! loss =  40264341712.09072
# Epoch  823  Completed! loss =  40264335263.15686
# Epoch  824  Completed! loss =  40264328874.246315
# Epoch  825  Completed! loss =  40264322544.7916
# Epoch  826  Completed! loss =  40264316274.23067
# Epoch  827  Completed! loss =  40264310062.00688
# Epoch  828  Completed! loss =  40264303907.568954
# Epoch  829  Completed! loss =  40264297810.37096
# Epoch  830  Completed! loss =  40264291769.87214
# Epoch  831  Completed! loss =  40264285785.53702
# Epoch  832  Completed! loss =  40264279856.83522
# Epoch  833  Completed! loss =  40264273983.24148
# Epoch  834  Completed! loss =  40264268164.23559
# Epoch  835  Completed! loss =  40264262399.30235
# Epoch  836  Completed! loss =  40264256687.93151
# Epoch  837  Completed! loss =  40264251029.6177
# Epoch  838  Completed! loss =  40264245423.86042
# Epoch  839  Completed! loss =  40264239870.16398
# Epoch  840  Completed! loss =  40264234368.03744
# Epoch  841  Completed! loss =  40264228916.99459
# Epoch  842  Completed! loss =  40264223516.55387
# Epoch  843  Completed! loss =  40264218166.238335
# Epoch  844  Completed! loss =  40264212865.575645
# Epoch  845  Completed! loss =  40264207614.09796
# Epoch  846  Completed! loss =  40264202411.34195
# Epoch  847  Completed! loss =  40264197256.84872
# Epoch  848  Completed! loss =  40264192150.16375
# Epoch  849  Completed! loss =  40264187090.83691
# Epoch  850  Completed! loss =  40264182078.42236
# Epoch  851  Completed! loss =  40264177112.47855
# Epoch  852  Completed! loss =  40264172192.56817
# Epoch  853  Completed! loss =  40264167318.25805
# Epoch  854  Completed! loss =  40264162489.119194
# Epoch  855  Completed! loss =  40264157704.726715
# Epoch  856  Completed! loss =  40264152964.65981
# Epoch  857  Completed! loss =  40264148268.50167
# Epoch  858  Completed! loss =  40264143615.83948
# Epoch  859  Completed! loss =  40264139006.26438
# Epoch  860  Completed! loss =  40264134439.37142
# Epoch  861  Completed! loss =  40264129914.759544
# Epoch  862  Completed! loss =  40264125432.03148
# Epoch  863  Completed! loss =  40264120990.79378
# Epoch  864  Completed! loss =  40264116590.65676
# Epoch  865  Completed! loss =  40264112231.23446
# Epoch  866  Completed! loss =  40264107912.14458
# Epoch  867  Completed! loss =  40264103633.00849
# Epoch  868  Completed! loss =  40264099393.4512
# Epoch  869  Completed! loss =  40264095193.101265
# Epoch  870  Completed! loss =  40264091031.590775
# Epoch  871  Completed! loss =  40264086908.55537
# Epoch  872  Completed! loss =  40264082823.63413
# Epoch  873  Completed! loss =  40264078776.4696
# Epoch  874  Completed! loss =  40264074766.70772
# Epoch  875  Completed! loss =  40264070793.997826
# Epoch  876  Completed! loss =  40264066857.99256
# Epoch  877  Completed! loss =  40264062958.347916
# Epoch  878  Completed! loss =  40264059094.723145
# Epoch  879  Completed! loss =  40264055266.78074
# Epoch  880  Completed! loss =  40264051474.18641
# Epoch  881  Completed! loss =  40264047716.60907
# Epoch  882  Completed! loss =  40264043993.72075
# Epoch  883  Completed! loss =  40264040305.19664
# Epoch  884  Completed! loss =  40264036650.71499
# Epoch  885  Completed! loss =  40264033029.95713
# Epoch  886  Completed! loss =  40264029442.607414
# Epoch  887  Completed! loss =  40264025888.35322
# Epoch  888  Completed! loss =  40264022366.88485
# Epoch  889  Completed! loss =  40264018877.895615
# Epoch  890  Completed! loss =  40264015421.08168
# Epoch  891  Completed! loss =  40264011996.14214
# Epoch  892  Completed! loss =  40264008602.778946
# Epoch  893  Completed! loss =  40264005240.69686
# Epoch  894  Completed! loss =  40264001909.60346
# Epoch  895  Completed! loss =  40263998609.2091
# Epoch  896  Completed! loss =  40263995339.2269
# Epoch  897  Completed! loss =  40263992099.37268
# Epoch  898  Completed! loss =  40263988889.36498
# Epoch  899  Completed! loss =  40263985708.92498
# Epoch  900  Completed! loss =  40263982557.776535
# Epoch  901  Completed! loss =  40263979435.646126
# Epoch  902  Completed! loss =  40263976342.2628
# Epoch  903  Completed! loss =  40263973277.35819
# Epoch  904  Completed! loss =  40263970240.666466
# Epoch  905  Completed! loss =  40263967231.92434
# Epoch  906  Completed! loss =  40263964250.87099
# Epoch  907  Completed! loss =  40263961297.24808
# Epoch  908  Completed! loss =  40263958370.79972
# Epoch  909  Completed! loss =  40263955471.27247
# Epoch  910  Completed! loss =  40263952598.41524
# Epoch  911  Completed! loss =  40263949751.97936
# Epoch  912  Completed! loss =  40263946931.71849
# Epoch  913  Completed! loss =  40263944137.38866
# Epoch  914  Completed! loss =  40263941368.74814
# Epoch  915  Completed! loss =  40263938625.55757
# Epoch  916  Completed! loss =  40263935907.579796
# Epoch  917  Completed! loss =  40263933214.57992
# Epoch  918  Completed! loss =  40263930546.325294
# Epoch  919  Completed! loss =  40263927902.585434
# Epoch  920  Completed! loss =  40263925283.13206
# Epoch  921  Completed! loss =  40263922687.73903
# Epoch  922  Completed! loss =  40263920116.182365
# Epoch  923  Completed! loss =  40263917568.24018
# Epoch  924  Completed! loss =  40263915043.69271
# Epoch  925  Completed! loss =  40263912542.32224
# Epoch  926  Completed! loss =  40263910063.913124
# Epoch  927  Completed! loss =  40263907608.25176
# Epoch  928  Completed! loss =  40263905175.12656
# Epoch  929  Completed! loss =  40263902764.32792
# Epoch  930  Completed! loss =  40263900375.648224
# Epoch  931  Completed! loss =  40263898008.881836
# Epoch  932  Completed! loss =  40263895663.82501
# Epoch  933  Completed! loss =  40263893340.275986
# Epoch  934  Completed! loss =  40263891038.03485
# Epoch  935  Completed! loss =  40263888756.90362
# Epoch  936  Completed! loss =  40263886496.68615
# Epoch  937  Completed! loss =  40263884257.188156
# Epoch  938  Completed! loss =  40263882038.21718
# Epoch  939  Completed! loss =  40263879839.58259
# Epoch  940  Completed! loss =  40263877661.09553
# Epoch  941  Completed! loss =  40263875502.568954
# Epoch  942  Completed! loss =  40263873363.81754
# Epoch  943  Completed! loss =  40263871244.657745
# Epoch  944  Completed! loss =  40263869144.907745
# Epoch  945  Completed! loss =  40263867064.38742
# Epoch  946  Completed! loss =  40263865002.91835
# Epoch  947  Completed! loss =  40263862960.32379
# Epoch  948  Completed! loss =  40263860936.42869
# Epoch  949  Completed! loss =  40263858931.05959
# Epoch  950  Completed! loss =  40263856944.04471
# Epoch  951  Completed! loss =  40263854975.21388
# Epoch  952  Completed! loss =  40263853024.3985
# Epoch  953  Completed! loss =  40263851091.431595
# Epoch  954  Completed! loss =  40263849176.147736
# Epoch  955  Completed! loss =  40263847278.38305
# Epoch  956  Completed! loss =  40263845397.97522
# Epoch  957  Completed! loss =  40263843534.763435
# Epoch  958  Completed! loss =  40263841688.5884
# Epoch  959  Completed! loss =  40263839859.29235
# Epoch  960  Completed! loss =  40263838046.71894
# Epoch  961  Completed! loss =  40263836250.71335
# Epoch  962  Completed! loss =  40263834471.122185
# Epoch  963  Completed! loss =  40263832707.793495
# Epoch  964  Completed! loss =  40263830960.57675
# Epoch  965  Completed! loss =  40263829229.32286
# Epoch  966  Completed! loss =  40263827513.88411
# Epoch  967  Completed! loss =  40263825814.114174
# Epoch  968  Completed! loss =  40263824129.8681
# Epoch  969  Completed! loss =  40263822461.002304
# Epoch  970  Completed! loss =  40263820807.37454
# Epoch  971  Completed! loss =  40263819168.84391
# Epoch  972  Completed! loss =  40263817545.2708
# Epoch  973  Completed! loss =  40263815936.51697
# Epoch  974  Completed! loss =  40263814342.4454
# Epoch  975  Completed! loss =  40263812762.9204
# Epoch  976  Completed! loss =  40263811197.80757
# Epoch  977  Completed! loss =  40263809646.97371
# Epoch  978  Completed! loss =  40263808110.28693
# Epoch  979  Completed! loss =  40263806587.616516
# Epoch  980  Completed! loss =  40263805078.83303
# Epoch  981  Completed! loss =  40263803583.80822
# Epoch  982  Completed! loss =  40263802102.41504
# Epoch  983  Completed! loss =  40263800634.527626
# Epoch  984  Completed! loss =  40263799180.0213
# Epoch  985  Completed! loss =  40263797738.77256
# Epoch  986  Completed! loss =  40263796310.65904
# Epoch  987  Completed! loss =  40263794895.55954
# Epoch  988  Completed! loss =  40263793493.353966
# Epoch  989  Completed! loss =  40263792103.92336
# Epoch  990  Completed! loss =  40263790727.14991
# Epoch  991  Completed! loss =  40263789362.916855
# Epoch  992  Completed! loss =  40263788011.10855
# Epoch  993  Completed! loss =  40263786671.61042
# Epoch  994  Completed! loss =  40263785344.308975
# Epoch  995  Completed! loss =  40263784029.09179
# Epoch  996  Completed! loss =  40263782725.84745
# Epoch  997  Completed! loss =  40263781434.465645
# Epoch  998  Completed! loss =  40263780154.837036
# Epoch  999  Completed! loss =  40263778886.85335
# Epoch  1000  Completed! loss =  40263777630.40729
# Training completed!!

# %% [markdown]
# ### **Evaluation and Visualization**
# Lets plot how loss varies with epochs

# %%
y_test_pred = y(x_test, a, b)
test_loss = loss(y_test_pred, y_test)
print("Loss on test data = ",test_loss)

# Visualization of loss

plt.plot(train_loss)                   # plot loss versus epochs
plt.title("Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()
# Out:
# Loss on test data =  47087163451.60995

# %% [markdown]
# ## **Deep Learning**
# In this section We will build a simple multilayer perceptron network(**MLP**) in TensorFlow

# %%
# Lets import the required libraries
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Load Dataset**
# We will be using MNIST dataset of handwritten digits
#
# Just run the cell below to load dataset

# %%
mnist = keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print("No. of training examples = ",x_train.shape[0])
print("Size of each image in dataset = ",x_train.shape[1:])
print("No. of test examples = ",x_test.shape[0])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# No. of training examples =  60000
# Size of each image in dataset =  (28, 28)
# No. of test examples =  10000

# %%
# Run this cell to visualize some of the images from dataset

n = 5    # = no. of images to visualize

index = np.random.choice(x_train.shape[0],5)  # choose random index
print("label: ",end="")

for i,ind in enumerate(index):
    plt.subplot(1,n,i+1)
    plt.imshow(x_train[ind],cmap="gray")
    plt.axis("off")
    print(y_train[ind],end="       ")

plt.show()
# Out:
# label: 7       8       3       6       0

# %% [markdown]
# #### Preprocess dataset
# Since we are building a MLP model the input to the model should be a vector rather than a 28 by 28 matrix.
#
# So your **First Task** is to flatten the images
#
# (Hint: use *reshape()* method of arrays...)
#
# Next, create validation dataset out of training dataset.
#
# You can use 50K images for training and 10K for validation

# %%
# Flatten the images into 1-d vectors

x_train_flatten = x_train.reshape(x_train.shape[0] , -1)                                       # flatten the images of training set
x_test_flatten = x_test.reshape(x_test.shape[0], -1)                                        # flatten th eimages of test set


# Divide the training data into training and validation data....

n_validation = 10000                                        # choose number of images to be used for validation

x_validation = x_train_flatten[:n_validation]
y_validation = y_train[:n_validation]

x_train_flatten = x_train_flatten[n_validation:]
y_train = y_train[n_validation:]

# %% [markdown]
# ### **Build a model**
# You can choose whatever architechure you want, but ensure that it is **not too deep** as that will take too much time to train and **not too shallow** as that will give very low accuracy.

# %%
model = keras.models.Sequential([
    layers.Dense(128, activation='relu', input_shape=(784,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Make a graphical representation of the model...
keras.utils.plot_model(model,show_shapes=True)
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 128)                 │         100,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 109,386 (427.29 KB)
#  Trainable params: 109,386 (427.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### Compile and Train
# Choose an optimizer- method that minimizes loss function
#
# **adam** optimizer is one of the popular choices. You should read about these online

# %%
model.compile(optimizer="adam",loss = "sparse_categorical_crossentropy",metrics=["accuracy"])

n_epochs = 15              # set number of epochs
batch_size = 512            # you can tweak with these parametrs
history = model.fit(x_train_flatten, y_train, validation_data=(x_validation, y_validation), epochs=n_epochs, batch_size=batch_size)
# Out:
# Epoch 1/15
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.5925 - loss: 21.3213 - val_accuracy: 0.8540 - val_loss: 1.6988
# Epoch 2/15
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8681 - loss: 1.3156 - val_accuracy: 0.8807 - val_loss: 1.0293
# Epoch 3/15
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8939 - loss: 0.7360 - val_accuracy: 0.8993 - val_loss: 0.7488
# Epoch 4/15
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9179 - loss: 0.4671 - val_accuracy: 0.9058 - val_loss: 0.6526
# Epoch 5/15
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9352 - loss: 0.3273 - val_accuracy: 0.9115 - val_loss: 0.5575
# Epoch 6/15
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9430 - loss: 0.2553 - val_accuracy: 0.9173 - val_loss: 0.4999
# Epoch 7/15
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9514 - loss: 0.2020 - val_accuracy: 0.9208 - val_loss: 0.4830
# Epoch 8/15
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9581 - loss: 0.1659 - val_accuracy: 0.9216 - val_loss: 0.4628
# Epoch 9/15
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9632 - loss: 0.1376 - val_accuracy: 0.9293 - val_loss: 0.4425
# Epoch 10/15
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9677 - loss: 0.1200 - val_accuracy: 0.9279 - val_loss: 0.4575
# Epoch 11/15
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9697 - loss: 0.1063 - val_accuracy: 0.9335 - val_loss: 0.4307
# Epoch 12/15
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9770 - loss: 0.0815 - val_accuracy: 0.9330 - val_loss: 0.4248
# Epoch 13/15
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9782 - loss: 0.0721 - val_accuracy: 0.9349 - val_loss: 0.4313
# Epoch 14/15
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9808 - loss: 0.0684 - val_accuracy: 0.9347 - val_loss: 0.4176
# Epoch 15/15
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9819 - loss: 0.0569 - val_accuracy: 0.9360 - val_loss: 0.4324

# %% [markdown]
# ### **Evaluate**
# Evaluate your model on test data.
#
# And Show some results

# %%
results = model.evaluate(x_test_flatten, y_test)
print("Loss = ",results[0])
print("Accuracy = ",results[1]*100,"%")

# Plot Accuracy...
plt.plot(history.history["accuracy"], label="Training accuracy")
plt.plot(history.history["val_accuracy"], label="validation Accuracy")
plt.title("Model accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# Similarly write code to plot loss...
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="validation Loss")
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9312 - loss: 0.4781
# Loss =  0.4145386219024658
# Accuracy =  94.04000043869019 %

# %% [markdown]
# Lets show our results on images from testing dataset

# %%
n = 3   # = no. of images to see predictions on

index = np.random.choice(x_test.shape[0], n)  # choose random index from test data
print("label: ")

for i,ind in enumerate(index):
    plt.subplot(1,n,i+1)
    plt.imshow(x_test[ind], cmap="gray")             # fill code to show images from test set
    plt.axis("off")
    print(y_test[ind],end="       ")

plt.show()
print("Predicted value: ")

# Now lets print the predictions

for i,ind in enumerate(index):
    # write code to predict and print digit in image
    # Hint: the output of the model is a 10-d vector which gives probabilties
    # The digit in the image would be the class for which probability is hghest...
    prediction = model.predict(x_test_flatten[ind].reshape(1, -1))
    digit = np.argmax(prediction)
    print(digit,end="      ")
# Out:
# label:
# 8       5       4
# Predicted value:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4
